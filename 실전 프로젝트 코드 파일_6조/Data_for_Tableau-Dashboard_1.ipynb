# %% [markdown]
# ## 라이브러리 호출 및 데이터 로드

# %%
# 라이브러리 호출
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import platform
import ast
from collections import Counter
import json
from pprint import pprint
import warnings
import platform

# 통계용 라이브러리 호출
from scipy import stats
import scikit_posthocs as sp
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from itertools import combinations
from matplotlib.patches import Patch
import pingouin as pg
from statsmodels.stats.proportion import proportions_ztest, proportion_effectsize, proportion_confint
from statsmodels.stats.power import NormalIndPower

warnings.filterwarnings('ignore')

# 한글 폰트 설정
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':  # Mac
    plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 컬럼 너비 제한 해제
pd.set_option('display.max_colwidth', None)

# %%
# 데이터 로드
df_champion = pd.read_csv('../../유저단위_게임데이터_상위랭커보존-stats_champion_1.csv')
df_combination = pd.read_csv('../../유저단위_게임데이터_상위랭커보존-stats_combination_1.csv')
df_champion_with_items = pd.read_csv("../../유저단위_게임데이터_상위랭커보존-stats_champion_items_1.csv")

# %% [markdown]
# ---
# #### **➡️ 경기데이터와 챔피언 정보가 담긴 테이블 제작**
# - `df_champion`

# %%
df_champion.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396204 entries, 0 to 396203
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           396204 non-null  str
#  1   game_id           396204 non-null  str
#  2   user_tier         396204 non-null  str
#  3   ranked            396204 non-null  int64
#  4   flag_1            396204 non-null  int64
#  5   flag_2            396204 non-null  int64
#  6   active_synergies  396204 non-null  str
#  7   top4_flag         396204 non-null  bool
#  8   ranked_1          396204 non-null  bool
#  9   champions         396204 non-null  str
# dtypes: bool(2), int64(3), str(5)
# memory usage: 24.9 MB

# %%
df_champion.head(1)
# Out:
#      user_id        game_id user_tier  ranked  flag_1  flag_2  \
# 0  KR-USER-1  KR_4291707834  platinum       5       0       0
#
#   active_synergies  top4_flag  ranked_1  \
# 0               {}      False     False
#
#                                                                                                                                                                                                                                                                                                                                                            champions
# 0  [{'name': 'ziggs', 'star': 1, 'cost': 1, 'origin': 'Rebel', 'class': "['Demolitionist']"}, {'name': 'ashe', 'star': 1, 'cost': 3, 'origin': 'Celestial', 'class': "['Sniper']"}, {'name': 'chogath', 'star': 1, 'cost': 4, 'origin': 'Void', 'class': "['Brawler']"}, {'name': 'ekko', 'star': 1, 'cost': 5, 'origin': 'Cybernetic', 'class': "['Infiltrator']"}]

# %% [markdown]
# #### 🔻분석단위를 챔피언 단위로 변경
# - 하나의 row = 한 유저가 참여한 하나의 게임
# - 챔피언마다 name, star, cost, origin, class 정보가 담겨있음

# %%
# champions 컬럼 문자열 → 리스트로 변환
df_champion['champions'] = df_champion['champions'].apply(ast.literal_eval)

# 챔피언 단위로 분리 (explode)
df_champ_exploded = df_champion.explode('champions')

# 딕셔너리 컬럼 분리
df_champ_exploded = pd.concat([
    df_champ_exploded.drop(columns='champions'),
    df_champ_exploded['champions'].apply(pd.Series)
], axis=1)
# champion 컬럼 분리 전
# champions = {'name': 'ziggs', 'star': 1, 'cost': 1, 'origin': 'Rebel', 'class': ['Demolitionist']}

# champion 컬럼 분리 후
# user_id    game_id  ranked  top4_flag   name   star  cost  origin         class
# KR-USER-1  KR_...     5       False     ziggs   1     1    Rebel     [Demolitionist]
# KR-USER-1  KR_...     5       False     ashe    1     3   Celestial     [Sniper]

print(df_champ_exploded.shape)
display(df_champ_exploded.head(1))
# Out:
# (3130701, 14)
#      user_id        game_id user_tier  ranked  flag_1  flag_2  \
# 0  KR-USER-1  KR_4291707834  platinum       5       0       0
#
#   active_synergies  top4_flag  ranked_1   name  star  cost origin  \
# 0               {}      False     False  ziggs     1     1  Rebel
#
#                class
# 0  ['Demolitionist']

# %%
# flag_1 제거 (챔피언 정보 누락된 row 제거)
df_champ_exploded = df_champ_exploded[df_champ_exploded['flag_1'] == 0]

print(df_champ_exploded.shape)
# Out:
# (3130701, 14)

# %%
# class 컬럼 확인
print(df_champ_exploded['class'].dtype)
display(df_champ_exploded['class'].head(1))
# Out:
# str
# 0    ['Demolitionist']
# Name: class, dtype: str

# %%
# 문자열 → 리스트 변환
df_champ_exploded['class'] = df_champ_exploded['class'].apply(ast.literal_eval)

# 시너지 단위로 분리
df_synergy_exploded = df_champ_exploded.explode('class')

# (4) 전체 유저가 가장 많이 선택한 시너지 Top 5
print('[전체 유저가 가장 많이 선택한 시너지 Top 5]')
display(df_synergy_exploded['class'].value_counts().head(5))
print()

# (5) 티어별로 유저가 가장 많이 선택한 시너지 Top 5
print('[티어별로 유저가 가장 많이 선택한 시너지 Top 5]')
top5_synergy_by_tier = (
    df_synergy_exploded
    .groupby('user_tier')['class']
    .value_counts()
    .groupby('user_tier')
    .head(5)
    .reset_index()
)
display(top5_synergy_by_tier)
# Out:
# [전체 유저가 가장 많이 선택한 시너지 Top 5]
# class
# Brawler        437345
# Blaster        428334
# Blademaster    407834
# Sorcerer       350769
# Vanguard       339726
# Name: count, dtype: int64
# [티어별로 유저가 가장 많이 선택한 시너지 Top 5]
#        user_tier        class  count
# 0     challenger      Blaster  91208
# 1     challenger      Brawler  88695
# 2     challenger  Blademaster  78710
# 3     challenger     Sorcerer  72460
# 4     challenger     Vanguard  70293
# 5        diamond      Brawler  92048
# 6        diamond  Blademaster  91083
# 7        diamond      Blaster  85087
# 8        diamond     Vanguard  61617
# 9        diamond  Mana-Reaver  61401
# 10  grand_master      Brawler  95032
# 11  grand_master      Blaster  92062
# 12  grand_master  Blademaster  79717
# 13  grand_master     Sorcerer  73463
# 14  grand_master     Vanguard  71806
# 15        master      Brawler  88508
# 16        master      Blaster  86631
# 17        master  Blademaster  77446
# 18        master     Sorcerer  73453
# 19        master     Vanguard  71577
# 20      platinum  Blademaster  80878
# 21      platinum      Blaster  73346
# 22      platinum      Brawler  73062
# 23      platinum     Sorcerer  70805
# 24      platinum     Vanguard  64433

# %% [markdown]
# ---
# #### **➡️ 콤비네이션 정보가 담긴 테이블 제작**
# - `df_combination`

# %%
print(df_combination.info())
display(df_combination.head(1))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396239 entries, 0 to 396238
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gameid               396239 non-null  str
#  1   user_tier            396239 non-null  str
#  2   ranked               396239 non-null  int64
#  3   user_id              396239 non-null  str
#  4   flag_1               396239 non-null  int64
#  5   flag_2               396239 non-null  int64
#  6   active_synergies     396239 non-null  str
#  7   top4_flag            396239 non-null  bool
#  8   ranked_1             396239 non-null  bool
#  9   combination_rebuild  396239 non-null  str
# dtypes: bool(2), int64(3), str(5)
# memory usage: 24.9 MB
# None
#           gameid user_tier  ranked    user_id  flag_1  flag_2  \
# 0  KR_4291707834  platinum       5  KR-USER-1       0       0
#
#   active_synergies  top4_flag  ranked_1  \
# 0               {}      False     False
#
#                                                                                                          combination_rebuild
# 0  {'Cybernetic': 1, 'Demolitionist': 1, 'Infiltrator': 1, 'Rebel': 1, 'Brawler': 1, 'Celestial': 1, 'Void': 1, 'Sniper': 1}

# %%
# (6) 전체 유저 기준에서 제작
# 문자열 → 딕셔너리 변환
df_combination['active_synergies'] = df_combination['active_synergies'].apply(ast.literal_eval)
df_combination['combination_rebuild'] = df_combination['combination_rebuild'].apply(ast.literal_eval)

# 활성화된 조합 리스트 추출
df_combination['combo_list_active'] = df_combination['active_synergies'].apply(
    lambda x: list(x.keys()) if x else []
)

# 보유한 조합 리스트 추출
df_combination['combo_list_rebuild'] = df_combination['combination_rebuild'].apply(
    lambda x: list(x.keys()) if x else []
)

# 가장 많이 활성화한 콤비네이션 Top 5
df_combo_active_exploded = df_combination.explode('combo_list_active')
print('[전체 유저가 가장 많이 활성화한 콤비네이션 Top 5]')
display(df_combo_active_exploded['combo_list_active'].value_counts().head(5))
print('='*50)

# 가장 많이 보유한 콤비네이션 Top 5
df_combo_rebuild_exploded = df_combination.explode('combo_list_rebuild')
print('[전체 유저가 가장 많이 보유한 콤비네이션 Top 5]')
display(df_combo_rebuild_exploded['combo_list_rebuild'].value_counts().head(5))
# Out:
# [전체 유저가 가장 많이 활성화한 콤비네이션 Top 5]
# combo_list_active
# Chrono        200384
# Celestial     137136
# Mercenary     127057
# Blaster       115469
# ManaReaver    113311
# Name: count, dtype: int64
# ==================================================
# [전체 유저가 가장 많이 보유한 콤비네이션 Top 5]
# combo_list_rebuild
# Chrono        262897
# Cybernetic    210292
# Vanguard      191019
# DarkStar      189045
# Celestial     180392
# Name: count, dtype: int64

# %%
# (7) 티어별 유저 기준에서 확인
# 활성화한 조합 Top 5
top5_active_by_tier = (
    df_combo_active_exploded
    .groupby('user_tier')['combo_list_active']
    .value_counts()
    .groupby('user_tier')
    .head(5)
    .reset_index()
)

display(top5_active_by_tier)
# Out:
#        user_tier combo_list_active  count
# 0     challenger            Chrono  38273
# 1     challenger         Celestial  28024
# 2     challenger           Blaster  25234
# 3     challenger         Mercenary  24362
# 4     challenger        ManaReaver  23896
# 5        diamond            Chrono  44033
# 6        diamond         Mercenary  28890
# 7        diamond         Celestial  28364
# 8        diamond        ManaReaver  24393
# 9        diamond       Blademaster  22950
# 10  grand_master            Chrono  46569
# 11  grand_master         Celestial  28652
# 12  grand_master         Mercenary  26426
# 13  grand_master           Blaster  24816
# 14  grand_master        ManaReaver  24321
# 15        master            Chrono  40273
# 16        master         Celestial  27800
# 17        master         Mercenary  24228
# 18        master           Blaster  23640
# 19        master        ManaReaver  23213
# 20      platinum            Chrono  31236
# 21      platinum         Celestial  24296
# 22      platinum         Mercenary  23151
# 23      platinum           Blaster  19596
# 24      platinum          Sorcerer  18393

# %%
# 보유한 조합 Top 5
top5_rebuild_by_tier = (
    df_combo_rebuild_exploded
    .groupby('user_tier')['combo_list_rebuild']
    .value_counts()
    .groupby('user_tier')
    .head(5)
    .reset_index()
)

display(top5_rebuild_by_tier)
# Out:
#        user_tier combo_list_rebuild  count
# 0     challenger             Chrono  49860
# 1     challenger         Cybernetic  42271
# 2     challenger           Vanguard  40567
# 3     challenger           Valkyrie  37310
# 4     challenger            Blaster  37012
# 5        diamond             Chrono  56554
# 6        diamond         Cybernetic  44308
# 7        diamond           DarkStar  38044
# 8        diamond           Valkyrie  37455
# 9        diamond        Blademaster  36878
# 10  grand_master             Chrono  58124
# 11  grand_master         Cybernetic  44310
# 12  grand_master           Vanguard  39792
# 13  grand_master           DarkStar  37754
# 14  grand_master          Celestial  36167
# 15        master             Chrono  52688
# 16        master         Cybernetic  42012
# 17        master           Vanguard  39998
# 18        master           DarkStar  38078
# 19        master          Celestial  36429
# 20      platinum             Chrono  45671
# 21      platinum           DarkStar  38322
# 22      platinum         Cybernetic  37391
# 23      platinum           Vanguard  36111
# 24      platinum          Celestial  34696

# %% [markdown]
# ---
# ---
# ### **➡️ 경기데이터와 챔피언 데이터, 아이템 데이터가 결합된 테이블**
# - `df_champion_with_items`

# %%
print(df_champion_with_items.info())
display(df_champion_with_items.head(1))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396239 entries, 0 to 396238
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameid          396239 non-null  str
#  1   user_tier       396239 non-null  str
#  2   ranked          396239 non-null  int64
#  3   champion        396239 non-null  str
#  4   item_count      396239 non-null  int64
#  5   champion_count  396239 non-null  int64
# dtypes: int64(3), str(3)
# memory usage: 18.1 MB
# None
#           gameid user_tier  ranked  \
# 0  KR_4291707834  platinum       5
#
#                                                                                                                                            champion  \
# 0  {'Ziggs': {'items': [7], 'star': 1}, 'Ashe': {'items': [9], 'star': 1}, 'ChoGath': {'items': [6], 'star': 1}, 'Ekko': {'items': [1], 'star': 1}}
#
#    item_count  champion_count
# 0           4               4

# %%
# 문자열 → 딕셔너리 변환
df_champion_with_items['champion'] = df_champion_with_items['champion'].apply(ast.literal_eval)

# 챔피언별 아이템, 별 정보 리스트로 변환
df_champion_with_items['champion'] = df_champion_with_items['champion'].apply(
    lambda x: [{'name': k, 'items': v['items'], 'star': v['star']} for k, v in x.items()]
)

# %%
# 챔피언 단위로 explode
df_champ_item_exploded = df_champion_with_items.explode('champion')

# 딕셔너리 컬럼 분리 -> 최종 데이터프레임
df_champ_item = pd.concat([
    df_champ_item_exploded.drop(columns='champion'),
    df_champ_item_exploded['champion'].apply(pd.Series)
], axis=1)

print(df_champ_item.shape)
display(df_champ_item.head(1))
# Out:
# (3130736, 9)
#           gameid user_tier  ranked  item_count  champion_count   name items  \
# 0  KR_4291707834  platinum       5           4               4  Ziggs   [7]
#
#    star   0
# 0   1.0 NaN

# %%
# 0 컬럼이 생기면 제거
if 0 in df_champ_item.columns:
    df_champ_item = df_champ_item.drop(columns=[0])

print(type(df_champ_item['items'].iloc[0])) # list
print(df_champ_item['items'].iloc[0])
# Out:
# <class 'list'>
# [7]

# %%
df_champ_item.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3130736 entries, 0 to 396238
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   gameid          str
#  1   user_tier       str
#  2   ranked          int64
#  3   item_count      int64
#  4   champion_count  int64
#  5   name            str
#  6   items           object
#  7   star            float64
# dtypes: float64(1), int64(3), object(1), str(3)
# memory usage: 215.0+ MB

# %%
# 아이템 테이블 로드
df_item = pd.read_csv('../../tft_game_dataset/TFT_Item_CurrentVersion.csv')

# %%
# 아이템 테이블 확인
print(df_item.info())
display(df_item.head(3))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      54 non-null     int64
#  1   name    54 non-null     str
# dtypes: int64(1), str(1)
# memory usage: 996.0 bytes
# None
#    id                  name
# 0   1            B.F. Sword
# 1   2           Recurve Bow
# 2   3  Needlessly Large Rod

# %%
# 아이템 ID + 이름 매핑 딕셔너리
item_map = dict(zip(df_item['id'], df_item['name']))

# items 컬럼의 ID를 이름으로 변환 -> 새로운 컬럼을 만들어서 진행
df_champ_item['item_names'] = df_champ_item['items'].apply(
    lambda x: [item_map.get(i, 'Unknown') for i in x] if isinstance(x, list) else []
)

# %%
display(df_champ_item.head(4))
# Out:
#           gameid user_tier  ranked  item_count  champion_count     name items  \
# 0  KR_4291707834  platinum       5           4               4    Ziggs   [7]
# 0  KR_4291707834  platinum       5           4               4     Ashe   [9]
# 0  KR_4291707834  platinum       5           4               4  ChoGath   [6]
# 0  KR_4291707834  platinum       5           4               4     Ekko   [1]
#
#    star         item_names
# 0   1.0     [Giant's Belt]
# 0   1.0  [Sparring Gloves]
# 0   1.0   [Negatron Cloak]
# 0   1.0       [B.F. Sword]

# %%
# 아이템 단위로 explode
df_champ_item_exploded2 = df_champ_item.explode('item_names')

# 챔피언별 아이템 사용 횟수 집계
champ_item_stats = (
    df_champ_item_exploded2
    .groupby(['name', 'item_names'])
    .size()
    .reset_index(name='count')
    .sort_values(['name', 'count'], ascending=[True, False])
)

# 챔피언별 Top 3 아이템 추출
champ_item_top3 = (
    champ_item_stats
    .groupby('name')
    .head(3)
    .reset_index(drop=True)
)

display(champ_item_top3.head(10))
# Out:
#           name           item_names  count
# 0         Ahri       Morellonomicon   3609
# 1         Ahri     Chalice of Favor   2656
# 2         Ahri       Thief's Gloves   1748
# 3        Annie        Zz'Rot Portal   2525
# 4        Annie          Quicksilver   2005
# 5        Annie         Bramble Vest   1555
# 6         Ashe      Spear of Shojin  11062
# 7         Ashe  Guinsoo's Rageblade   6127
# 8         Ashe         Statikk Shiv   6065
# 9  AurelionSol     Seraph's Embrace   2507

# %%
# 챔피언별 Top 3 아이템을 1행으로 합치기
champ_item_pivot = champ_item_top3.groupby('name')['item_names'].apply(
    lambda x: list(x)
).reset_index()

# item_1, item_2, item_3 컬럼으로 분리
champ_item_pivot[['item_1', 'item_2', 'item_3']] = pd.DataFrame(
    champ_item_pivot['item_names'].tolist(), index=champ_item_pivot.index
)

champ_item_pivot = champ_item_pivot.drop(columns='item_names')
display(champ_item_pivot.head(5))
# Out:
#           name            item_1               item_2                  item_3
# 0         Ahri    Morellonomicon     Chalice of Favor          Thief's Gloves
# 1        Annie     Zz'Rot Portal          Quicksilver            Bramble Vest
# 2         Ashe   Spear of Shojin  Guinsoo's Rageblade            Statikk Shiv
# 3  AurelionSol  Seraph's Embrace       Morellonomicon  Demolitionist's Charge
# 4   Blitzcrank            Zephyr     Chalice of Favor             Rebel Medal

# %%
# champion_item_top3.csv 저장
champ_item_pivot.to_csv('champion_item_top3.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### **✅ champion_item_top3.csv 파일의 컬럼 명세서**
#
# | 컬럼명 | 타입 | 설명 | 예시 |
# |---|---|---|---|
# | name | str | 챔피언 이름 | Ahri |
# | item_1 | str | 가장 많이 사용한 아이템 | Morellonomicon |
# | item_2 | str | 두 번째로 많이 사용한 아이템 | Chalice of Favor |
# | item_3 | str | 세 번째로 많이 사용한 아이템 | Thief's Gloves |
#
# > 태블로에서 티어, 유저 순위, 챔피언 코스트 필터 적용 예정

# %% [markdown]
# ---
# #### champion_stats.csv 파일 제작

# %%
# 현재 데이터셋에서 한 게임당 몇 명의 플레이어가 배정되어 있는지 확인
game_user_count = df_champion.groupby('game_id')['user_id'].nunique()
print(game_user_count.value_counts())
# Out:
# user_id
# 8    49339
# 7      209
# 1       11
# 6        3
# Name: count, dtype: int64

# %%
# 전체 유저-게임 수 (gameid + user_id 기준 중복 제거)
total_user_games = len(df_champ_exploded[['game_id', 'user_id']].drop_duplicates())

# 챔피언별 통계 집계
champ_stats = df_champ_exploded.groupby(['name', 'cost']).agg(
    pick_count=('name', 'count'),
    avg_rank=('ranked', 'mean'),
    win_rate=('ranked_1', 'mean'),
    top4_rate=('top4_flag', 'mean')
).reset_index()

# 픽률 = pick_count(챔피언 단위) / total_user_games(유저-게임 단위)
champ_stats['pick_rate'] = champ_stats['pick_count'] / total_user_games

display(champ_stats.head(10))
# Out:
#           name  cost  pick_count  avg_rank  win_rate  top4_rate  pick_rate
# 0         ahri     2       36489  4.578256  0.131053   0.485407   0.092096
# 1        annie     2       52599  4.446111  0.134375   0.509991   0.132757
# 2         ashe     3       89109  4.389781  0.132085   0.517883   0.224907
# 3  aurelionsol     5       23117  3.538565  0.199723   0.688671   0.058346
# 4   blitzcrank     2      120040  4.412537  0.118386   0.517011   0.302975
# 5      caitlyn     1       21972  4.517704  0.122565   0.501729   0.055456
# 6      chogath     4       94857  4.252095  0.126306   0.547782   0.239415
# 7       darius     2       33400  4.687575  0.126677   0.458054   0.084300
# 8         ekko     5       45233  3.882365  0.167378   0.616629   0.114166
# 9       ezreal     3      105788  4.380932  0.118038   0.522488   0.267004

# %%
# champion_stats.csv 저장 -> 티어 정보가 없는 전체 유저 기준의 데이터
champ_stats.to_csv('champion_stats.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### **✅ champion_stats.csv** 데이터 명세서
#
# | 컬럼명 | 타입 | 설명 | 예시 |
# |---|---|---|---|
# | name | str | 챔피언 이름 | ahri |
# | cost | int | 챔피언 코스트 | 2 |
# | pick_count | int | 챔피언 등장 횟수 (챔피언 단위) | 36489 |
# | avg_rank | float | 평균 등수 | 4.578 |
# | win_rate | float | 승률 (1위 비율) | 0.131 |
# | top4_rate | float | 순방율 (top4 비율) | 0.485 |
# | pick_rate | float | 픽률 (pick_count / 전체 유저-게임 수) | 0.092 |
#
#
# > 픽률이 1을 초과할 수 있음 (한 게임에서 여러 유저가 같은 챔피언을 선택 가능하기 때문)
#
# > 태블로에서 티어, 유저 순위, 챔피언 코스트 필터 적용 예정

# %% [markdown]
# ---
# #### combination_stats.csv 제작

# %%
# 조합별 통계 집계
# 픽률의 분모 - 동일한 게임+유저에 해당하는 행은 제거
total_user_games_combo = len(df_combination[['gameid', 'user_id']].drop_duplicates())

combo_stats = df_combo_active_exploded.groupby('combo_list_active').agg(
    pick_count=('combo_list_active', 'count'),
    avg_rank=('ranked', 'mean'),
    win_rate=('ranked_1', 'mean'),
    top4_rate=('top4_flag', 'mean')
).reset_index()

# 픽률 계산 = 전체 행에서 해당 조합이 선택된 행의 개수 / 전체 유저-게임 수
combo_stats['pick_rate'] = combo_stats['pick_count'] / total_user_games_combo

display(combo_stats.head(10))
# Out:
#   combo_list_active  pick_count  avg_rank  win_rate  top4_rate  pick_rate
# 0       Blademaster      103932  4.424624  0.127901   0.513547   0.262296
# 1           Blaster      115469  4.261672  0.129273   0.545081   0.291413
# 2           Brawler      101015  4.334059  0.122229   0.532792   0.254935
# 3         Celestial      137136  4.287058  0.142530   0.538247   0.346094
# 4            Chrono      200384  4.244925  0.138374   0.548607   0.505715
# 5        Cybernetic       41664  4.466446  0.123704   0.506384   0.105149
# 6          DarkStar       48084  4.311268  0.145059   0.530779   0.121351
# 7     Demolitionist       45954  4.091657  0.170497   0.571093   0.115975
# 8       Infiltrator       67183  4.302904  0.144039   0.537487   0.169552
# 9        ManaReaver      113311  4.167292  0.149165   0.560546   0.285966

# %%
# combination_stats.csv 저장 -> 티어 정보가 없는 전체 유저 기준의 데이터
combo_stats.to_csv('combination_stats.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### **✅ combination_stats.csv 데이터명세서**
#
# | 컬럼명 | 타입 | 설명 | 예시 |
# |---|---|---|---|
# | combo_list_active | str | 활성화된 조합 이름 | Chrono |
# | pick_count | int | 해당 조합이 활성화된 횟수 | 200384 |
# | avg_rank | float | 평균 등수 | 4.245 |
# | win_rate | float | 승률 (1위 비율) | 0.138 |
# | top4_rate | float | 순방율 (top4 비율) | 0.549 |
# | pick_rate | float | 픽률 (pick_count / 전체 유저-게임 수) | 0.506 |
#
# > 픽률 분모: 전체 유저-게임 수 (gameid + user_id 기준 중복 제거)
# > 활성화된 조합만 포함 (active_synergies 기준)
# > 태블로에서 티어, 유저 순위 필터 적용 예정

# %% [markdown]
# ---
# ### champion, champion+item 테이블에 user_tier 붙이기
# - 티어별로 필터를 걸 때 활용 가능

# %% [markdown]
# (1) champion_stats_by_tier.csv 제작

# %%
# 티어별 전체 유저-게임 수
total_user_games_by_tier = df_champ_exploded.groupby('user_tier')[['game_id', 'user_id']].apply(
    lambda x: len(x.drop_duplicates())
).reset_index(name='total_user_games')

# 챔피언별 통계 집계 (티어별)
champ_stats_by_tier = df_champ_exploded.groupby(['name', 'cost', 'user_tier']).agg(
    pick_count=('name', 'count'),
    avg_rank=('ranked', 'mean'),
    win_rate=('ranked_1', 'mean'),
    top4_rate=('top4_flag', 'mean')
).reset_index()

# 티어별 픽률 계산
champ_stats_by_tier = champ_stats_by_tier.merge(total_user_games_by_tier, on='user_tier')
champ_stats_by_tier['pick_rate'] = champ_stats_by_tier['pick_count'] / champ_stats_by_tier['total_user_games']
champ_stats_by_tier = champ_stats_by_tier.drop(columns='total_user_games')

display(champ_stats_by_tier.head(5))
# Out:
#    name  cost     user_tier  pick_count  avg_rank  win_rate  top4_rate  \
# 0  ahri     2    challenger        8499  4.515355  0.141428   0.495941
# 1  ahri     2       diamond        5124  4.623341  0.119048   0.480874
# 2  ahri     2  grand_master        7167  4.650481  0.135901   0.467281
# 3  ahri     2        master        7832  4.551583  0.138151   0.490552
# 4  ahri     2      platinum        7867  4.577603  0.116182   0.488369
#
#    pick_rate
# 0   0.106344
# 1   0.064489
# 2   0.089640
# 3   0.097986
# 4   0.102242

# %%
# champion_stats_by_tier.csv 저장 -> 유저의 티어 데이터가 포함된 데이터
champ_stats_by_tier.to_csv('champion_stats_by_tier.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### **✅ champion_stats_by_tier.csv 데이터 명세서**
#
# | 컬럼명 | 타입 | 설명 | 예시 |
# |---|---|---|---|
# | name | str | 챔피언 이름 | ahri |
# | cost | int | 챔피언 코스트 | 2 |
# | user_tier | str | 유저 티어 | challenger |
# | pick_count | int | 챔피언 등장 횟수 | 8499 |
# | avg_rank | float | 평균 등수 | 4.515 |
# | win_rate | float | 승률 (1위 비율) | 0.141 |
# | top4_rate | float | 순방율 (top4 비율) | 0.496 |
# | pick_rate | float | 픽률 (pick_count / 티어별 전체 유저-게임 수) | 0.106 |
#
# > 태블로에서 티어, 유저 순위, 챔피언 코스트 필터 적용 예정

# %% [markdown]
# (2) combunation_stats_by_tier.csv 제작

# %%
# 티어별 전체 유저-게임 수
total_user_games_combo_by_tier = df_combination.groupby('user_tier')[['gameid', 'user_id']].apply(
    lambda x: len(x.drop_duplicates())
).reset_index(name='total_user_games')

# 조합별 통계 집계 (티어별)
combo_stats_by_tier = df_combo_active_exploded.groupby(['combo_list_active', 'user_tier']).agg(
    pick_count=('combo_list_active', 'count'),
    avg_rank=('ranked', 'mean'),
    win_rate=('ranked_1', 'mean'),
    top4_rate=('top4_flag', 'mean')
).reset_index()

# 티어별 픽률 계산
combo_stats_by_tier = combo_stats_by_tier.merge(total_user_games_combo_by_tier, on='user_tier')
combo_stats_by_tier['pick_rate'] = combo_stats_by_tier['pick_count'] / combo_stats_by_tier['total_user_games']
combo_stats_by_tier = combo_stats_by_tier.drop(columns='total_user_games')

display(combo_stats_by_tier.head(5))
# Out:
#   combo_list_active     user_tier  pick_count  avg_rank  win_rate  top4_rate  \
# 0       Blademaster    challenger       20926  4.443229  0.125538   0.509271
# 1       Blademaster       diamond       22950  4.364488  0.132244   0.524793
# 2       Blademaster  grand_master       21598  4.383415  0.128947   0.522224
# 3       Blademaster        master       20253  4.460623  0.126055   0.507283
# 4       Blademaster      platinum       18205  4.487888  0.125954   0.500961
#
#    pick_rate
# 0   0.261820
# 1   0.288832
# 2   0.270110
# 3   0.253384
# 4   0.236533

# %%
# combination_stats_by_tier.csv 저장 -> 유저의 티어 데이터가 포함된 데이터
combo_stats_by_tier.to_csv('combination_stats_by_tier.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### **✅ combination_stats_by_tier.csv 데이터명세서**
#
# | 컬럼명 | 타입 | 설명 | 예시 |
# |---|---|---|---|
# | combo_list_active | str | 활성화된 조합 이름 | Blademaster |
# | user_tier | str | 유저 티어 | challenger |
# | pick_count | int | 해당 조합이 활성화된 횟수 | 20926 |
# | avg_rank | float | 평균 등수 | 4.443 |
# | win_rate | float | 승률 (1위 비율) | 0.126 |
# | top4_rate | float | 순방율 (top4 비율) | 0.509 |
# | pick_rate | float | 픽률 (pick_count / 티어별 전체 유저-게임 수) | 0.262 |
#
# > 활성화된 조합만 포함 (active_synergies 기준)
# > 태블로에서 티어, 유저 순위 필터 적용 예정

# %% [markdown]
# ---
# ---
# ##### **(1) 티어별 챔피언 승률/선택률 분포(의사결정 사분면 제작용)**
# - Aurelionsol을 제거하지 않은 버전

# %%
# 왜도(skewness) 확인 → 0에 가까울수록 정규분포에 가까움
print(f"win_rate  왜도: {champ_stats_by_tier['win_rate'].skew():.3f}")
print(f"pick_rate 왜도: {champ_stats_by_tier['pick_rate'].skew():.3f}")
# Out:
# win_rate  왜도: 0.889
# pick_rate 왜도: 0.541

# %%
# ================================
# 티어별 IQR 기반 이상치 탐지 - 데이터 개수가 너무 적어서 확인용
# ================================
tiers_1 = champ_stats_by_tier['user_tier'].unique()
result_list_1 = []

for tier_1 in tiers_1:
    tier_df_1 = champ_stats_by_tier[champ_stats_by_tier['user_tier'] == tier_1].copy()
    
    # win_rate IQR
    Q1_w_s, Q3_w_s = tier_df_1['win_rate'].quantile(0.25), tier_df_1['win_rate'].quantile(0.75)
    IQR_w_s = Q3_w_s - Q1_w_s
    tier_df_1['win_rate_outlier'] = (
        (tier_df_1['win_rate'] < Q1_w_s - 1.5 * IQR_w_s) |
        (tier_df_1['win_rate'] > Q3_w_s + 1.5 * IQR_w_s)
    )
    
    # pick_rate IQR
    Q1_p_s, Q3_p_s = tier_df_1['pick_rate'].quantile(0.25), tier_df_1['pick_rate'].quantile(0.75)
    IQR_p_s = Q3_p_s - Q1_p_s
    tier_df_1['pick_rate_outlier'] = (
        (tier_df_1['pick_rate'] < Q1_p_s - 1.5 * IQR_p_s) |
        (tier_df_1['pick_rate'] > Q3_p_s + 1.5 * IQR_p_s)
    )
    
    # 둘 다 이상치일 때만
    tier_df_1['is_outlier'] = tier_df_1['win_rate_outlier'] & tier_df_1['pick_rate_outlier']
    
    result_list_1.append(tier_df_1)

result_df_1 = pd.concat(result_list_1, ignore_index=True)

# 결과 확인
outliers = result_df_1[result_df_1['is_outlier']].sort_values(['user_tier', 'win_rate'], ascending=[True, False])
print(outliers[['name', 'user_tier', 'win_rate', 'pick_rate']])
print(f"\n총 이상치 수: {result_df_1['is_outlier'].sum()}개")
# Out:
# Empty DataFrame
# Columns: [name, user_tier, win_rate, pick_rate]
# Index: []
#
# 총 이상치 수: 0개

# %%
import matplotlib.patches as mpatches

# ================================
# 1. 기준선 설정 (중앙값 기준)
# ================================
win_rate_median_s  = champ_stats_by_tier['win_rate'].median()
pick_rate_median_s = champ_stats_by_tier['pick_rate'].median()

print(f"win_rate 기준선 (중앙값): {win_rate_median_s:.3f}")
print(f"pick_rate 기준선 (중앙값): {pick_rate_median_s:.3f}")

# ================================
# 2. 4분면 분류
# ================================
def classify_matrix(row):
    high_win_s  = row['win_rate']  >= win_rate_median_s
    high_pick_s = row['pick_rate'] >= pick_rate_median_s
    
    if high_win_s and high_pick_s:
        return '높은 승률 + 높은 선택률'
    elif high_win_s and not high_pick_s:
        return '높은 승률 + 낮은 선택률'
    elif not high_win_s and high_pick_s:
        return '낮은 승률 + 높은 선택률'
    else:
        return '낮은 승률 + 낮은 선택률'

champ_stats_by_tier['matrix_type'] = champ_stats_by_tier.apply(classify_matrix, axis=1)

# IQR 이상치 여부도 반영
champ_stats_by_tier['is_outlier'] = result_df_1['is_outlier'].values

# ================================
# 의사결정 매트릭스 출력
# ================================
print("\n========== 의사결정 매트릭스 ==========")
for matrix_type in ['높은 승률 + 높은 선택률', '높은 승률 + 낮은 선택률',
                    '낮은 승률 + 높은 선택률', '낮은 승률 + 낮은 선택률']:
    subset = champ_stats_by_tier[champ_stats_by_tier['matrix_type'] == matrix_type]\
        .sort_values('win_rate', ascending=False)\
        [['name', 'user_tier', 'win_rate', 'pick_rate', 'is_outlier']]
    print(f"\n{matrix_type} ({len(subset)}개)")
    print(subset.to_string(index=False))

# ================================
# 시각화 - 티어별 사분면 산점도
# ================================
tiers_s = champ_stats_by_tier['user_tier'].unique()
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

color_map = {
    '높은 승률 + 높은 선택률': 'red',
    '높은 승률 + 낮은 선택률': 'gold',
    '낮은 승률 + 높은 선택률': 'orange',
    '낮은 승률 + 낮은 선택률': 'steelblue'
}

for i, tier in enumerate(tiers_s):
    ax = axes[i]
    tier_df = champ_stats_by_tier[champ_stats_by_tier['user_tier'] == tier]
    
    # 기준선
    ax.axvline(x=pick_rate_median_s, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=win_rate_median_s,  color='gray', linestyle='--', alpha=0.5)
    
    # 사분면 배경색
    ax.axvspan(pick_rate_median_s, tier_df['pick_rate'].max() + 0.01, 
            ymin=0.5, alpha=0.05, color='red')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_s, 
            ymin=0.5, alpha=0.05, color='gold')
    ax.axvspan(pick_rate_median_s, tier_df['pick_rate'].max() + 0.01, 
            ymax=0.5, alpha=0.05, color='orange')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_s, 
            ymax=0.5, alpha=0.05, color='steelblue')
    
    # 산점도
    for mtype, color in color_map.items():
        subset = tier_df[tier_df['matrix_type'] == mtype]
        ax.scatter(subset['pick_rate'], subset['win_rate'],
                color=color, alpha=0.6, s=60, label=mtype)
    
    # 챔피언 이름 표시
    for _, row in tier_df.iterrows():
        ax.annotate(row['name'], (row['pick_rate'], row['win_rate']),
                    fontsize=7, ha='left', va='bottom')
    
    # 사분면 라벨
    x_min, x_max = tier_df['pick_rate'].min(), tier_df['pick_rate'].max()
    y_min, y_max = tier_df['win_rate'].min(),  tier_df['win_rate'].max()
    ax.text(x_max, y_max, '높은 승률 + 높은 선택률', ha='right', va='top', fontsize=9, color='red', alpha=0.4, fontweight='bold')
    ax.text(x_min, y_max, '높은 승률 + 낮은 선택률', ha='left', va='top', fontsize=9, color='goldenrod', alpha=0.4, fontweight='bold')
    ax.text(x_max, y_min, '낮은 승률 + 높은 선택률', ha='right', va='bottom', fontsize=9, color='orange', alpha=0.4, fontweight='bold')
    ax.text(x_min, y_min, '낮은 승률 + 낮은 선택률', ha='left', va='bottom', fontsize=9, color='steelblue', alpha=0.4, fontweight='bold')
    
    ax.set_title(f'{tier}', fontsize=12, fontweight='bold')
    ax.set_xlabel('pick_rate')
    ax.set_ylabel('win_rate')
    
# 빈 subplot 숨기기
for j in range(len(tiers_s), len(axes)):
    axes[j].set_visible(False)

# 범례
patches = [mpatches.Patch(color=c, label=l) for l, c in color_map.items()]
fig.legend(handles=patches, loc='lower center', ncol=4, fontsize=10, bbox_to_anchor=(0.5, -0.02))

plt.suptitle('챔피언 의사결정 매트릭스 (티어별)', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()
# Out:
# win_rate 기준선 (중앙값): 0.132
# pick_rate 기준선 (중앙값): 0.139
#
# ========== 의사결정 매트릭스 ==========
#
# 높은 승률 + 높은 선택률 (60개)
#        name    user_tier  win_rate  pick_rate  is_outlier
#        lulu   challenger  0.208584   0.176664       False
#        lulu     platinum  0.205111   0.157138       False
#        lulu grand_master  0.204812   0.150226       False
#        lulu       master  0.198450   0.159815       False
#      soraka grand_master  0.188600   0.142184       False
#      thresh      diamond  0.183262   0.153695       False
# missfortune     platinum  0.179332   0.225239       False
#      thresh       master  0.177699   0.177280       False
#      thresh grand_master  0.177323   0.192488       False
#         lux grand_master  0.174353   0.171951       False
# missfortune      diamond  0.170770   0.270401       False
#      thresh   challenger  0.169603   0.205243       False
#         lux       master  0.166102   0.177155       False
#        ekko   challenger  0.165939   0.146209       False
#         lux   challenger  0.164901   0.200776       False
#      velkoz grand_master  0.164539   0.143059       False
# missfortune       master  0.155802   0.265232       False
# missfortune grand_master  0.155274   0.285793       False
#         lux     platinum  0.154455   0.172409       False
#       karma   challenger  0.154229   0.176214       False
# missfortune   challenger  0.150071   0.281732       False
#      velkoz      diamond  0.149316   0.141688       False
#        fizz     platinum  0.149299   0.151030       False
#      velkoz     platinum  0.148311   0.138891       False
#       shaco   challenger  0.148283   0.181507       False
#     chogath     platinum  0.145513   0.204796       False
#        fizz   challenger  0.145329   0.144645       False
#       annie   challenger  0.144666   0.147210       False
#       karma     platinum  0.144054   0.178452       False
#    kassadin      diamond  0.142724   0.298140       False
#       kayle      diamond  0.142151   0.244538       False
#      rumble   challenger  0.141497   0.147147       False
#      rumble     platinum  0.141442   0.157489       False
#       kayle   challenger  0.141076   0.241867       False
#          vi     platinum  0.140723   0.254065       False
#       kayle grand_master  0.140693   0.225357       False
#       karma       master  0.139802   0.153297       False
#       annie     platinum  0.138937   0.151537       False
#    kassadin     platinum  0.138502   0.219949       False
#       shaco     platinum  0.138379   0.166236       False
#       kayle       master  0.137630   0.225347       False
#      wukong      diamond  0.136948   0.273220       False
#        ashe      diamond  0.136626   0.230845       False
#        fizz      diamond  0.136145   0.143841       False
#  blitzcrank     platinum  0.135630   0.264852       False
#      wukong grand_master  0.135430   0.287494       False
#       kayle     platinum  0.135314   0.212165       False
#       kaisa   challenger  0.135149   0.149337       False
#       rakan      diamond  0.134967   0.175682       False
#    malphite     platinum  0.134956   0.225824       False
#      irelia      diamond  0.134177   0.215830       False
#     chogath      diamond  0.133897   0.263278       False
#       shaco       master  0.133132   0.153272       False
#        jhin   challenger  0.133095   0.182195       False
#        ashe     platinum  0.132867   0.219105       False
#        ashe   challenger  0.132699   0.220833       False
#       poppy grand_master  0.132685   0.165810       False
#    kassadin grand_master  0.132525   0.300214       False
#    kassadin       master  0.131933   0.277468       False
#      ezreal     platinum  0.131923   0.226681       False
#
# 높은 승률 + 낮은 선택률 (70개)
#        name    user_tier  win_rate  pick_rate  is_outlier
# aurelionsol       master  0.207080   0.054072       False
# aurelionsol grand_master  0.206053   0.060335       False
# aurelionsol      diamond  0.205533   0.064602       False
#        lulu      diamond  0.204392   0.136390       False
# aurelionsol   challenger  0.200767   0.055468       False
#      xerath   challenger  0.195279   0.077915       False
#      xerath grand_master  0.185761   0.061136       False
#        ekko     platinum  0.185083   0.117967       False
#      thresh     platinum  0.184794   0.134187       False
#      xerath       master  0.183821   0.067584       False
#      xerath      diamond  0.181920   0.044968       False
# aurelionsol     platinum  0.177753   0.057249       False
#      soraka       master  0.173737   0.135669       False
#      soraka   challenger  0.173295   0.123323       False
#      xerath     platinum  0.172831   0.055871       False
#      soraka      diamond  0.171202   0.087407       False
#   gangplank   challenger  0.170768   0.034072       False
#   gangplank       master  0.165875   0.052646       False
#   gangplank      diamond  0.165839   0.131746       False
#        ekko      diamond  0.164409   0.088263       False
#   gangplank grand_master  0.163413   0.062149       False
#        sona grand_master  0.162177   0.136968       False
#   gangplank     platinum  0.161759   0.106375       False
#        ekko       master  0.160333   0.117203       False
#        ekko grand_master  0.160321   0.101184       False
#      velkoz       master  0.160075   0.127474       False
#         lux      diamond  0.159244   0.121791       False
# twistedfate grand_master  0.156692   0.122047       False
#        sona       master  0.155078   0.128112       False
#         zoe grand_master  0.154203   0.137318       False
#       neeko   challenger  0.151327   0.115015       False
#        sona   challenger  0.148860   0.101539       False
#       rakan grand_master  0.148398   0.135104       False
#       neeko grand_master  0.147793   0.078196       False
#       neeko       master  0.147631   0.100338       False
#      velkoz   challenger  0.147626   0.101201       False
#      soraka     platinum  0.147541   0.126051       False
#         zoe       master  0.147464   0.125310       False
#    jarvaniv grand_master  0.145624   0.099458       False
#       rakan       master  0.145334   0.130589       False
# twistedfate       master  0.144154   0.095121       False
#       rakan   challenger  0.143768   0.098086       False
#      syndra   challenger  0.141945   0.105868       False
# twistedfate      diamond  0.141438   0.120394       False
#        ahri   challenger  0.141428   0.106344       False
#       karma grand_master  0.140993   0.114080       False
#      syndra grand_master  0.140503   0.085012       False
#         zoe   challenger  0.139818   0.112938       False
#     caitlyn grand_master  0.138527   0.052819       False
#        ahri       master  0.138151   0.097986       False
#    jarvaniv   challenger  0.137378   0.077965       False
#     xinzhao   challenger  0.137367   0.085623       False
#         zoe      diamond  0.137240   0.082901       False
#      syndra       master  0.136954   0.096284       False
#        fizz       master  0.136794   0.133529       False
#    jarvaniv       master  0.136725   0.089766       False
#       xayah grand_master  0.136663   0.138469       False
#       kaisa     platinum  0.136469   0.133992       False
#      darius   challenger  0.136410   0.060723       False
#        ahri grand_master  0.135901   0.089640       False
#     xinzhao       master  0.135890   0.102102       False
#      khazix     platinum  0.134765   0.116785       False
#     xinzhao grand_master  0.134673   0.087114       False
#       karma      diamond  0.134627   0.101150       False
#       annie       master  0.134344   0.132053       False
#       xayah       master  0.133524   0.113750       False
#      darius       master  0.133333   0.083886       False
# twistedfate     platinum  0.133090   0.092573       False
#      darius grand_master  0.132753   0.068966       False
#    jarvaniv      diamond  0.132048   0.128574       False
#
# 낮은 승률 + 높은 선택률 (70개)
#        name    user_tier  win_rate  pick_rate  is_outlier
#      rumble       master  0.131743   0.140548       False
#        jinx     platinum  0.130421   0.203184       False
#        jhin     platinum  0.130216   0.167574       False
#      wukong     platinum  0.130155   0.230359       False
#          vi      diamond  0.130059   0.298241       False
#      wukong       master  0.129873   0.257688       False
#        ashe       master  0.129501   0.229638       False
#        ashe grand_master  0.128742   0.223932       False
#      graves      diamond  0.128189   0.184970       False
#      irelia grand_master  0.128145   0.192863       False
#       xayah      diamond  0.128026   0.168987       False
#      irelia     platinum  0.127395   0.187913       False
#      khazix      diamond  0.127340   0.153292       False
#    malphite      diamond  0.126908   0.284522       False
#        jhin      diamond  0.126615   0.143237       False
#  blitzcrank      diamond  0.126485   0.312437       False
#       poppy       master  0.126467   0.157788       False
#       jayce      diamond  0.125905   0.201722       False
#        jhin       master  0.125706   0.170587       False
#        shen      diamond  0.125650   0.263630       False
#    kassadin   challenger  0.125057   0.273549       False
#      rumble      diamond  0.124802   0.167099       False
#      ezreal      diamond  0.124449   0.242713       False
#      irelia   challenger  0.123539   0.201251       False
#     chogath       master  0.123479   0.237495       False
#        shen grand_master  0.123067   0.240967       False
#       rakan     platinum  0.122733   0.157671       False
#      irelia       master  0.121841   0.188628       False
#        jinx      diamond  0.121688   0.236533       False
#      wukong   challenger  0.121170   0.235235       False
#        shen       master  0.120949   0.218879       False
#       jayce     platinum  0.120720   0.184093       False
#        sona     platinum  0.119964   0.143219       False
#          vi       master  0.119734   0.318066       False
#        jhin grand_master  0.119099   0.156054       False
#    malphite       master  0.118960   0.243888       False
#        jinx       master  0.118672   0.214750       False
#      graves       master  0.118655   0.167859       False
#     chogath grand_master  0.118429   0.261491       False
#       jayce       master  0.118106   0.187814       False
#          vi grand_master  0.117719   0.339462       False
#        shen   challenger  0.117344   0.218381       False
#      graves grand_master  0.117188   0.192113       False
#      lucian     platinum  0.117153   0.165404       False
#          vi   challenger  0.116746   0.347147       False
#       leona   challenger  0.116105   0.175663       False
#       jayce   challenger  0.116018   0.168569       False
#      ezreal       master  0.115604   0.276292       False
#        shen     platinum  0.114933   0.210098       False
#  blitzcrank       master  0.114881   0.307869       False
#      ezreal grand_master  0.114510   0.292722       False
#       jayce grand_master  0.114314   0.178780       False
#    malphite grand_master  0.113105   0.261416       False
#     chogath   challenger  0.113013   0.228854       False
#        jinx grand_master  0.112671   0.230786       False
# mordekaiser   challenger  0.111839   0.162450       False
#  blitzcrank grand_master  0.111260   0.326229       False
#      graves   challenger  0.110190   0.168969       False
#    malphite   challenger  0.110013   0.231682       False
#        jinx   challenger  0.109021   0.210836       False
#      ezreal   challenger  0.108302   0.294957       False
# mordekaiser     platinum  0.107465   0.156852       False
#  blitzcrank   challenger  0.106772   0.302115       False
#       poppy     platinum  0.106685   0.142894       False
#       leona grand_master  0.105793   0.143997       False
#      lucian   challenger  0.104233   0.184747       False
# mordekaiser       master  0.103922   0.144827       False
#       leona       master  0.103396   0.147379       False
#      lucian       master  0.096592   0.159702       False
#      lucian grand_master  0.092197   0.150038       False
#
# 낮은 승률 + 낮은 선택률 (60개)
#        name    user_tier  win_rate  pick_rate  is_outlier
#        sona      diamond  0.128959   0.116429       False
#        fizz grand_master  0.128722   0.114267       False
#       fiora   challenger  0.128657   0.131294       False
#     caitlyn      diamond  0.127454   0.092328       False
#       shaco grand_master  0.127015   0.127225       False
#      darius      diamond  0.126212   0.105102       False
#      rumble grand_master  0.126145   0.127012       False
#     caitlyn       master  0.125930   0.042024       False
#       annie grand_master  0.125576   0.108664       False
#         zoe     platinum  0.125000   0.105114       False
#       annie      diamond  0.124559   0.124987       False
# twistedfate   challenger  0.123965   0.054404       False
#       fiora grand_master  0.123429   0.117444       False
#       xayah   challenger  0.123277   0.092568       False
#      khazix   challenger  0.122921   0.115841       False
#       kaisa       master  0.122722   0.136607       False
#       shaco      diamond  0.122680   0.130185       False
#       neeko      diamond  0.121957   0.053766       False
#      graves     platinum  0.121817   0.132718       False
#       kaisa      diamond  0.121317   0.138806       False
#     xinzhao      diamond  0.121101   0.102887       False
#     caitlyn   challenger  0.120273   0.020183       False
#      khazix       master  0.120043   0.117665       False
#    jarvaniv     platinum  0.119374   0.131951       False
#        ahri      diamond  0.119048   0.064489       False
#      syndra      diamond  0.117816   0.061317       False
#       fiora       master  0.116902   0.109696       False
#       poppy      diamond  0.116766   0.114252       False
#      syndra     platinum  0.116699   0.101566       False
#       poppy   challenger  0.116647   0.137625       False
#      khazix grand_master  0.116609   0.115518       False
#        ahri     platinum  0.116182   0.102242       False
#       neeko     platinum  0.115672   0.109546       False
#       xayah     platinum  0.114933   0.126194       False
#       kaisa grand_master  0.114838   0.124923       False
#       fiora      diamond  0.114572   0.100622       False
#       fiora     platinum  0.113360   0.104672       False
#     xinzhao     platinum  0.113044   0.133706       False
#      darius     platinum  0.111445   0.103671       False
#    masteryi       master  0.109445   0.055899       False
#       leona     platinum  0.105496   0.123192       False
#       yasuo       master  0.104102   0.056725       False
#       yasuo   challenger  0.103607   0.051689       False
#     caitlyn     platinum  0.102187   0.070713       False
#    masteryi   challenger  0.102068   0.047810       False
#    masteryi      diamond  0.101485   0.076269       False
#       yasuo      diamond  0.100576   0.076457       False
#       ziggs     platinum  0.099315   0.053129       False
#       ziggs       master  0.098627   0.024609       False
#    masteryi     platinum  0.098000   0.103308       False
#       ziggs      diamond  0.096801   0.059807       False
#       yasuo     platinum  0.095800   0.106765       False
#       leona      diamond  0.095579   0.098495       False
#      lucian      diamond  0.094772   0.136252       False
# mordekaiser grand_master  0.094403   0.122022       False
#    masteryi grand_master  0.094392   0.040811       False
#       ziggs   challenger  0.094378   0.018694       False
#       yasuo grand_master  0.093341   0.041137       False
#       ziggs grand_master  0.091011   0.022401       False
# mordekaiser      diamond  0.089593   0.087797       False

# %%
# 태블로 대시보드 작업용 계산결과(사분면 제작용)
tier_medians = champ_stats_by_tier.groupby('user_tier').agg(
    win_rate_median=('win_rate', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians)
# Out:
#       user_tier  win_rate_median  pick_rate_median
# 0    challenger         0.134122          0.147178
# 1       diamond         0.127740          0.133999
# 2  grand_master         0.132605          0.137143
# 3        master         0.132532          0.138578
# 4      platinum         0.131172          0.143057

# %% [markdown]
# ##### **(2) 티어별 시너지 승률/선택률 분포(의사결정 사분면 제작용)**
# - Starship을 제거하지 않은 버전

# %%
# 티어별 중앙값 계산
tier_medians_combo = combo_stats_by_tier.groupby('user_tier').agg(
    win_rate_median=('win_rate', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians_combo)
# Out:
#       user_tier  win_rate_median  pick_rate_median
# 0    challenger         0.143541          0.179231
# 1       diamond         0.141134          0.180007
# 2  grand_master         0.137194          0.183342
# 3        master         0.142338          0.182510
# 4      platinum         0.147799          0.166099

# %%
# 왜도(skewness) 확인 → 0에 가까울수록 정규분포에 가까움
print(f"win_rate  왜도: {combo_stats_by_tier['win_rate'].skew():.3f}")
print(f"pick_rate 왜도: {combo_stats_by_tier['pick_rate'].skew():.3f}")
# Out:
# win_rate  왜도: 0.909
# pick_rate 왜도: 1.114

# %%
# ================================
# 기준선 설정 (중앙값 기준)
# ================================
win_rate_median_c  = combo_stats_by_tier['win_rate'].median()
pick_rate_median_c = combo_stats_by_tier['pick_rate'].median()

print(f"win_rate 기준선 (중앙값): {win_rate_median_c:.3f}")
print(f"pick_rate 기준선 (중앙값): {pick_rate_median_c:.3f}")

# ================================
# 사분면 분류
# ================================
def classify_matrix_combo(row):
    high_win  = row['win_rate']  >= win_rate_median_c
    high_pick = row['pick_rate'] >= pick_rate_median_c
    
    if high_win and high_pick:
        return '높은 승률 + 높은 선택률'
    elif high_win and not high_pick:
        return '높은 승률 + 낮은 선택률'
    elif not high_win and high_pick:
        return '낮은 승률 + 높은 선택률'
    else:
        return '낮은 승률 + 낮은 선택률'

combo_stats_by_tier['matrix_type'] = combo_stats_by_tier.apply(classify_matrix_combo, axis=1)

# ================================
# 의사결정 매트릭스 출력
# ================================
print("\n========== 시너지 의사결정 매트릭스 ==========")
for matrix_type in ['높은 승률 + 높은 선택률', '높은 승률 + 낮은 선택률',
                    '낮은 승률 + 높은 선택률', '낮은 승률 + 낮은 선택률']:
    subset = combo_stats_by_tier[combo_stats_by_tier['matrix_type'] == matrix_type]\
        .sort_values('win_rate', ascending=False)\
        [['combo_list_active', 'user_tier', 'win_rate', 'pick_rate']]
    print(f"\n{matrix_type} ({len(subset)}개)")
    print(subset.to_string(index=False))

# ================================
# 시각화 - 티어별 사분면 산점도
# ================================
tiers_c = combo_stats_by_tier['user_tier'].unique()
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

color_map = {
    '높은 승률 + 높은 선택률': 'red',
    '높은 승률 + 낮은 선택률': 'gold',
    '낮은 승률 + 높은 선택률': 'orange',
    '낮은 승률 + 낮은 선택률': 'steelblue'
}

for i, tier in enumerate(tiers_c):
    ax = axes[i]
    tier_df = combo_stats_by_tier[combo_stats_by_tier['user_tier'] == tier]

    # 기준선
    ax.axvline(x=pick_rate_median_c, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=win_rate_median_c,  color='gray', linestyle='--', alpha=0.5)

    # 사분면 배경색
    ax.axvspan(pick_rate_median_c, tier_df['pick_rate'].max() + 0.01,
            ymin=0.5, alpha=0.05, color='red')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_c,
            ymin=0.5, alpha=0.05, color='gold')
    ax.axvspan(pick_rate_median_c, tier_df['pick_rate'].max() + 0.01,
            ymax=0.5, alpha=0.05, color='orange')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_c,
            ymax=0.5, alpha=0.05, color='steelblue')

    # 산점도
    for mtype, color in color_map.items():
        subset = tier_df[tier_df['matrix_type'] == mtype]
        ax.scatter(subset['pick_rate'], subset['win_rate'],
                color=color, alpha=0.6, s=60, label=mtype)

    # 시너지 이름 표시 (모든 점)
    for _, row in tier_df.iterrows():
        ax.annotate(row['combo_list_active'], (row['pick_rate'], row['win_rate']),
                    fontsize=7, ha='left', va='bottom')

    # 사분면 라벨
    x_min, x_max = tier_df['pick_rate'].min(), tier_df['pick_rate'].max()
    y_min, y_max = tier_df['win_rate'].min(),  tier_df['win_rate'].max()
    ax.text(x_max, y_max, '높은 승률 + 높은 선택률', ha='right', va='top',   fontsize=9, color='red',       alpha=0.4, fontweight='bold')
    ax.text(x_min, y_max, '높은 승률 + 낮은 선택률', ha='left',  va='top',   fontsize=9, color='goldenrod', alpha=0.4, fontweight='bold')
    ax.text(x_max, y_min, '낮은 승률 + 높은 선택률', ha='right', va='bottom', fontsize=9, color='orange',   alpha=0.4, fontweight='bold')
    ax.text(x_min, y_min, '낮은 승률 + 낮은 선택률', ha='left',  va='bottom', fontsize=9, color='steelblue',alpha=0.4, fontweight='bold')

    ax.set_title(f'{tier}', fontsize=12, fontweight='bold')
    ax.set_xlabel('pick_rate')
    ax.set_ylabel('win_rate')

# 빈 subplot 숨기기
for j in range(len(tiers_c), len(axes)):
    axes[j].set_visible(False)

# 범례
patches = [mpatches.Patch(color=c, label=l) for l, c in color_map.items()]
fig.legend(handles=patches, loc='lower center', ncol=4, fontsize=10, bbox_to_anchor=(0.5, -0.02))

plt.suptitle('시너지 의사결정 매트릭스 (티어별)', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()
# Out:
# win_rate 기준선 (중앙값): 0.143
# pick_rate 기준선 (중앙값): 0.179
#
# ========== 시너지 의사결정 매트릭스 ==========
#
# 높은 승률 + 높은 선택률 (27개)
# combo_list_active    user_tier  win_rate  pick_rate
#            Mystic grand_master  0.192279   0.184980
#            Mystic   challenger  0.188551   0.185336
#            Mystic       master  0.183058   0.184461
#          Valkyrie      diamond  0.173221   0.181782
#         Mercenary     platinum  0.169453   0.300795
#          Valkyrie   challenger  0.164940   0.205343
#         Mercenary      diamond  0.164071   0.363588
#          Sorcerer   challenger  0.162198   0.270216
#          Sorcerer grand_master  0.160309   0.260955
#          Valkyrie grand_master  0.159758   0.187956
#          Valkyrie       master  0.159035   0.182510
#          Sorcerer       master  0.156829   0.262617
#        ManaReaver     platinum  0.155821   0.227217
#         Mercenary grand_master  0.155150   0.330490
#         Mercenary       master  0.154986   0.303115
#        ManaReaver      diamond  0.154758   0.306992
#          Sorcerer     platinum  0.153700   0.238976
#          Sorcerer      diamond  0.152705   0.217247
#       Infiltrator   challenger  0.150576   0.179231
#         Mercenary   challenger  0.150439   0.304811
#            Chrono     platinum  0.148258   0.405842
#        ManaReaver grand_master  0.148185   0.304165
#        ManaReaver       master  0.146685   0.290417
#         Celestial     platinum  0.144962   0.315672
#            Chrono      diamond  0.144800   0.554167
#           Blaster     platinum  0.143805   0.254606
#         Celestial      diamond  0.143492   0.356968
#
# 높은 승률 + 낮은 선택률 (31개)
# combo_list_active    user_tier  win_rate  pick_rate
#          Starship       master  0.207032   0.054085
#          Starship grand_master  0.205888   0.060318
#          Starship      diamond  0.205533   0.064600
#          Starship   challenger  0.200947   0.055477
#            Mystic      diamond  0.189343   0.123763
#     Demolitionist   challenger  0.184905   0.089184
#     Demolitionist     platinum  0.180451   0.117506
#            Mystic     platinum  0.178113   0.166099
#          Starship     platinum  0.177753   0.057233
#     Demolitionist       master  0.174175   0.097761
#          Valkyrie     platinum  0.171865   0.148702
#             Rebel grand_master  0.163124   0.117684
#             Rebel       master  0.161885   0.111210
#              Void     platinum  0.161822   0.053634
#      StarGuardian grand_master  0.160721   0.137419
#     Demolitionist grand_master  0.160432   0.105315
#     Demolitionist      diamond  0.160405   0.170493
#             Rebel   challenger  0.156974   0.110153
#          DarkStar   challenger  0.156039   0.157560
#       Infiltrator     platinum  0.155088   0.170569
#         Protector   challenger  0.154239   0.105374
#             Rebel      diamond  0.154008   0.125437
#         Protector grand_master  0.152153   0.140308
#         Protector       master  0.151123   0.135356
#      StarGuardian       master  0.151119   0.127411
#              Void      diamond  0.149463   0.072667
#          DarkStar     platinum  0.148395   0.148143
#         MechPilot     platinum  0.147799   0.132214
#             Rebel     platinum  0.144968   0.110776
#         MechPilot   challenger  0.144607   0.137917
#      StarGuardian   challenger  0.143541   0.115058
#
# 낮은 승률 + 높은 선택률 (31개)
# combo_list_active    user_tier  win_rate  pick_rate
#         Celestial   challenger  0.142556   0.350629
#         Celestial       master  0.142338   0.347804
#        ManaReaver   challenger  0.141990   0.298980
#            Sniper      diamond  0.141134   0.189849
#           Brawler     platinum  0.141026   0.214939
#         Celestial grand_master  0.139676   0.358329
#       Infiltrator      diamond  0.139202   0.180007
#            Chrono grand_master  0.137194   0.582404
#            Chrono       master  0.136990   0.503853
#            Sniper     platinum  0.136934   0.180183
#            Sniper   challenger  0.134705   0.183072
#           Blaster      diamond  0.133931   0.279179
#          Vanguard      diamond  0.133066   0.228788
#            Sniper       master  0.133031   0.184987
#       Blademaster      diamond  0.132244   0.288832
#          Vanguard grand_master  0.131474   0.231341
#            Sniper grand_master  0.130900   0.183342
#           Brawler      diamond  0.129582   0.276700
#       Blademaster grand_master  0.128947   0.270110
#           Blaster       master  0.126311   0.295759
#       Blademaster       master  0.126055   0.253384
#       Blademaster     platinum  0.125954   0.236533
#            Chrono   challenger  0.125807   0.478861
#       Blademaster   challenger  0.125538   0.261820
#          Vanguard       master  0.125537   0.203703
#           Blaster grand_master  0.123549   0.310355
#           Blaster   challenger  0.122295   0.315721
#          Vanguard     platinum  0.121557   0.193891
#           Brawler       master  0.118710   0.255361
#           Brawler grand_master  0.115027   0.279640
#           Brawler   challenger  0.110068   0.246669
#
# 낮은 승률 + 낮은 선택률 (26개)
# combo_list_active    user_tier  win_rate  pick_rate
#          DarkStar       master  0.143318   0.131990
#       SpacePirate   challenger  0.141098   0.066062
#       Infiltrator       master  0.138979   0.166358
#      StarGuardian      diamond  0.138717   0.085555
#         Protector      diamond  0.137762   0.175036
#       SpacePirate grand_master  0.137043   0.091258
#       SpacePirate       master  0.136727   0.095346
#         MechPilot       master  0.136011   0.122707
#       Infiltrator grand_master  0.135614   0.151701
#              Void       master  0.135435   0.041661
#          DarkStar grand_master  0.135268   0.096986
#              Void grand_master  0.135043   0.043897
#       SpacePirate      diamond  0.134573   0.136726
#          DarkStar      diamond  0.130878   0.072793
#        Cybernetic     platinum  0.130492   0.098472
#         MechPilot      diamond  0.127715   0.116477
#         MechPilot grand_master  0.127154   0.101601
#         Protector     platinum  0.126158   0.162721
#        Cybernetic   challenger  0.125791   0.136365
#      StarGuardian     platinum  0.124845   0.114999
#              Void   challenger  0.123687   0.032168
#        Cybernetic      diamond  0.122744   0.080898
#        Cybernetic grand_master  0.121197   0.102776
#       SpacePirate     platinum  0.120893   0.115856
#        Cybernetic       master  0.118150   0.106843
#          Vanguard   challenger  0.115213   0.165718

# %% [markdown]
# ##### **(3) 티어별 챔피언의 평균 등수 - 중앙값 (태블로 대시보드)**

# %%
# 티어별 챔피언의 평균등수
tier_medians_champ_rank = champ_stats_by_tier.groupby('user_tier').agg(
    avg_rank_median=('avg_rank', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians_champ_rank)
# Out:
#       user_tier  avg_rank_median  pick_rate_median
# 0    challenger         4.461448          0.147178
# 1       diamond         4.437711          0.133999
# 2  grand_master         4.425906          0.137143
# 3        master         4.450374          0.138578
# 4      platinum         4.393321          0.143057

# %%
# 티어별 시너지의 평균등수
tier_medians_combo_rank = combo_stats_by_tier.groupby('user_tier').agg(
    avg_rank_median=('avg_rank', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians_combo_rank)
# Out:
#       user_tier  avg_rank_median  pick_rate_median
# 0    challenger         4.311412          0.179231
# 1       diamond         4.267176          0.180007
# 2  grand_master         4.325926          0.183342
# 3        master         4.313707          0.182510
# 4      platinum         4.216785          0.166099
