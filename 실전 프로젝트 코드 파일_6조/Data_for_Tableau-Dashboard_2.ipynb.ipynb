# %% [markdown]
# ## 라이브러리 호출 및 데이터 로드

# %%
# 라이브러리 호출
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import platform
import ast
from collections import Counter
import json
from pprint import pprint
import warnings
import platform

# 통계용 라이브러리 호출
from scipy import stats
import scikit_posthocs as sp
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from itertools import combinations
from matplotlib.patches import Patch
import pingouin as pg
from statsmodels.stats.proportion import proportions_ztest, proportion_effectsize, proportion_confint
from statsmodels.stats.power import NormalIndPower

warnings.filterwarnings('ignore')

# 한글 폰트 설정
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':  # Mac
    plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 컬럼 너비 제한 해제
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ---
# ---
# ### **y축: 승률에서 평균 등수로 변경**
# - 챔피언에서는 `Aurelionsol`을 제거하고, 시너지에서는 `Starship`을 제거함.
# - 제거한 이유
#     - `Aurelionsol`: 당시 메타상 강한 덱 중 하나인 아우솔은 승률에 비해 굉장히 낮은 선택률을 갖고 있어
# 이상치로 가장 먼저 탐색되는 데이터이다. 그러나 해당 시즌의 설계상 아우솔은 5코스트의 챔피언으로서 가장 강력한 챔피언 중 하나였고, 그에 반해 매우 뽑기 어려운 챔피언이었다. 따라서 아우솔을 이상치로 판단하기에는 어려움이 있을 것으로 판단된다.
#     - `Starship`: 시즌 3에서 스타쉽은 아우솔을 획득하면 활성화되는 시너지로, 사실 아우솔을 갖고 있다는 것과 거의 동일한 의미를 갖고 있는 시너지이다. 따라서 해당 시너지도 이상치로 판단하기에는 어려움이 있을 것으로 판단된다.

# %%
# 데이터로드
combo_stats_by_tier = pd.read_csv('../실전 프로젝트 코드 파일_6조/data/combination_stats_by_tier.csv')
champ_stats = pd.read_csv('../실전 프로젝트 코드 파일_6조/data/champion_stats.csv')
champ_item_pivot = pd.read_csv('../실전 프로젝트 코드 파일_6조/data/champion_item_top3.csv')
champ_stats_by_tier = pd.read_csv('../실전 프로젝트 코드 파일_6조/data/champion_stats_by_tier.csv')
combo_stats = pd.read_csv('../실전 프로젝트 코드 파일_6조/data/combination_stats.csv')

# %%
# Starship 지우기
combo_stats_by_tier_except = combo_stats_by_tier.drop(
    combo_stats_by_tier[combo_stats_by_tier['combo_list_active'] == 'Starship'].index
)

print("Starship 남은 개수:", (combo_stats_by_tier_except['combo_list_active'] == 'Starship').sum())
# Out:
# Starship 남은 개수: 0

# %%
# Aurelionsol 지우기
champ_stats_by_tier_except = champ_stats_by_tier.drop(
    champ_stats_by_tier[champ_stats_by_tier['name'] == 'aurelionsol'].index
)

print("Aurelionsol 남은 개수:", (champ_stats_by_tier_except ['name'] == 'aurelionsol').sum())
# Out:
# Aurelionsol 남은 개수: 0

# %%
# 아우솔 및 스타십 지우지 않은 버전 사용하기 위해서 활성화 필요
# 아닌 경우 위의 지우는 코드 활성화

# combo_stats_by_tier_except = combo_stats_by_tier
# champ_stats_by_tier_except = champ_stats_by_tier

# %% [markdown]
# ---
# ---
#
# ##### **(1) 티어별 챔피언 승률/선택률 분포(의사결정 사분면 제작용)**
# - y축을 평균 등수로 변경한 버전

# %%
# 왜도(skewness) 확인 → 0에 가까울수록 정규분포에 가까움
print(f"win_rate  왜도: {champ_stats_by_tier_except['win_rate'].skew():.3f}")
print(f"pick_rate 왜도: {champ_stats_by_tier_except['pick_rate'].skew():.3f}")

print(f"avg_rank  왜도: {champ_stats_by_tier_except['avg_rank'].skew():.3f}")
# Out:
# win_rate  왜도: 0.811
# pick_rate 왜도: 0.533
# avg_rank  왜도: -0.709

# %%
# avg_rank version
# ================================
# 티어별 IQR 기반 이상치 탐지 - 데이터 개수가 너무 적어서 확인용
# ================================
tiers_1 = champ_stats_by_tier_except['user_tier'].unique()
result_list_1 = []

for tier_1 in tiers_1:
    tier_df_1 = champ_stats_by_tier_except[champ_stats_by_tier_except['user_tier'] == tier_1].copy()
    
    # win_rate IQR
    Q1_w_s, Q3_w_s = tier_df_1['avg_rank'].quantile(0.25), tier_df_1['avg_rank'].quantile(0.75)
    IQR_w_s = Q3_w_s - Q1_w_s
    tier_df_1['avg_rank_outlier'] = (
        (tier_df_1['avg_rank'] < Q1_w_s - 1.5 * IQR_w_s) |
        (tier_df_1['avg_rank'] > Q3_w_s + 1.5 * IQR_w_s)
    )
    
    # pick_rate IQR
    Q1_p_s, Q3_p_s = tier_df_1['pick_rate'].quantile(0.25), tier_df_1['pick_rate'].quantile(0.75)
    IQR_p_s = Q3_p_s - Q1_p_s
    tier_df_1['pick_rate_outlier'] = (
        (tier_df_1['pick_rate'] < Q1_p_s - 1.5 * IQR_p_s) |
        (tier_df_1['pick_rate'] > Q3_p_s + 1.5 * IQR_p_s)
    )
    
    # 둘 다 이상치일 때만
    tier_df_1['is_outlier'] = tier_df_1['avg_rank_outlier'] & tier_df_1['pick_rate_outlier']
    
    result_list_1.append(tier_df_1)

result_df_1 = pd.concat(result_list_1, ignore_index=True)

# 결과 확인
outliers = result_df_1[result_df_1['is_outlier']].sort_values(['user_tier', 'win_rate'], ascending=[True, False])
print(outliers[['name', 'user_tier', 'avg_rank', 'pick_rate']])
print(f"\n총 이상치 수: {result_df_1['is_outlier'].sum()}개")
# Out:
# Empty DataFrame
# Columns: [name, user_tier, avg_rank, pick_rate]
# Index: []
#
# 총 이상치 수: 0개

# %%
# ================================
# 티어별 IQR 기반 이상치 탐지 - 데이터 개수가 너무 적어서 확인용
# ================================
tiers_1 = champ_stats_by_tier_except['user_tier'].unique()
result_list_1 = []

for tier_1 in tiers_1:
    tier_df_1 = champ_stats_by_tier_except[champ_stats_by_tier_except['user_tier'] == tier_1].copy()
    
    # win_rate IQR
    Q1_w_s, Q3_w_s = tier_df_1['win_rate'].quantile(0.25), tier_df_1['win_rate'].quantile(0.75)
    IQR_w_s = Q3_w_s - Q1_w_s
    tier_df_1['win_rate_outlier'] = (
        (tier_df_1['win_rate'] < Q1_w_s - 1.5 * IQR_w_s) |
        (tier_df_1['win_rate'] > Q3_w_s + 1.5 * IQR_w_s)
    )
    
    # pick_rate IQR
    Q1_p_s, Q3_p_s = tier_df_1['pick_rate'].quantile(0.25), tier_df_1['pick_rate'].quantile(0.75)
    IQR_p_s = Q3_p_s - Q1_p_s
    tier_df_1['pick_rate_outlier'] = (
        (tier_df_1['pick_rate'] < Q1_p_s - 1.5 * IQR_p_s) |
        (tier_df_1['pick_rate'] > Q3_p_s + 1.5 * IQR_p_s)
    )
    
    # 둘 다 이상치일 때만
    tier_df_1['is_outlier'] = tier_df_1['win_rate_outlier'] & tier_df_1['pick_rate_outlier']
    
    result_list_1.append(tier_df_1)

result_df_1 = pd.concat(result_list_1, ignore_index=True)

# 결과 확인
outliers = result_df_1[result_df_1['is_outlier']].sort_values(['user_tier', 'win_rate'], ascending=[True, False])
print(outliers[['name', 'user_tier', 'win_rate', 'pick_rate']])
print(f"\n총 이상치 수: {result_df_1['is_outlier'].sum()}개")
# Out:
# Empty DataFrame
# Columns: [name, user_tier, win_rate, pick_rate]
# Index: []
#
# 총 이상치 수: 0개

# %%
import matplotlib.patches as mpatches

# ================================
# 기준선 설정 (중앙값 기준)
# ================================
avg_rank_median_s  = champ_stats_by_tier_except['avg_rank'].median()
pick_rate_median_s = champ_stats_by_tier_except['pick_rate'].median()

print(f"avg_rank 기준선 (중앙값): {avg_rank_median_s:.3f}")
print(f"pick_rate 기준선 (중앙값): {pick_rate_median_s:.3f}")

# ================================
# 사분면 분류
# ================================
def classify_matrix(row):
    high_rank_s  = row['avg_rank']  <= avg_rank_median_s
    high_pick_s = row['pick_rate'] >= pick_rate_median_s
    
    if high_rank_s and high_pick_s:
        return '높은 평균 순위 + 높은 선택률'
    elif high_rank_s and not high_pick_s:
        return '높은 평균 순위 + 낮은 선택률'
    elif not high_rank_s and high_pick_s:
        return '낮은 평균 순위 + 높은 선택률'
    else:
        return '낮은 평균 순위 + 낮은 선택률'

champ_stats_by_tier_except['matrix_type'] = champ_stats_by_tier_except.apply(classify_matrix, axis=1)

# IQR 이상치 여부도 반영
champ_stats_by_tier_except['is_outlier'] = result_df_1['is_outlier'].values

# ================================
# 의사결정 매트릭스 출력
# ================================
print("\n========== 의사결정 매트릭스 ==========")
for matrix_type in ['높은 평균 순위 + 높은 선택률', '높은 평균 순위 + 낮은 선택률',
                    '낮은 평균 순위 + 높은 선택률', '낮은 평균 순위 + 낮은 선택률']:
    subset = champ_stats_by_tier_except[champ_stats_by_tier_except['matrix_type'] == matrix_type]\
        .sort_values('avg_rank', ascending=True)\
        [['name', 'user_tier', 'avg_rank', 'pick_rate', 'is_outlier']]
    print(f"\n{matrix_type} ({len(subset)}개)")
    print(subset.to_string(index=False))

# ================================
# 시각화 - 티어별 사분면 산점도
# ================================
tiers_s = champ_stats_by_tier_except['user_tier'].unique()
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

color_map = {
    '높은 평균 순위 + 높은 선택률': 'red',
    '높은 평균 순위 + 낮은 선택률': 'gold',
    '낮은 평균 순위 + 높은 선택률': 'orange',
    '낮은 평균 순위 + 낮은 선택률': 'steelblue'
}

for i, tier in enumerate(tiers_s):
    ax = axes[i]
    tier_df = champ_stats_by_tier_except[champ_stats_by_tier_except['user_tier'] == tier]
    
    # Y축 범위 미리 계산
    y_min_val = tier_df['avg_rank'].min()
    y_max_val = tier_df['avg_rank'].max()
    
    # 기준선
    ax.axvline(x=pick_rate_median_s, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=avg_rank_median_s,  color='gray', linestyle='--', alpha=0.5)
    
    # 사분면 배경색
    ax.axvspan(pick_rate_median_s, tier_df['pick_rate'].max() + 0.01, 
            ymin=0.5, alpha=0.05, color='red')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_s, 
            ymin=0.5, alpha=0.05, color='gold')
    ax.axvspan(pick_rate_median_s, tier_df['pick_rate'].max() + 0.01, 
            ymax=0.5, alpha=0.05, color='orange')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_s, 
            ymax=0.5, alpha=0.05, color='steelblue')
    
    # 산점도
    for mtype, color in color_map.items():
        subset = tier_df[tier_df['matrix_type'] == mtype]
        ax.scatter(subset['pick_rate'], subset['avg_rank'],
                color=color, alpha=0.6, s=60, label=mtype)

    # 챔피언 이름 표시
    for _, row in tier_df.iterrows():
        ax.annotate(row['name'], (row['pick_rate'], row['avg_rank']),
                    fontsize=7, ha='left', va='bottom')
    
    # 사분면 라벨
    x_min = tier_df['pick_rate'].min()
    x_max = tier_df['pick_rate'].max()
    
    ax.text(x_max, y_max_val, '높은 평균 순위 + 높은 선택률', ha='right', va='top', fontsize=9, color='red', alpha=0.4, fontweight='bold')
    ax.text(x_min, y_max_val, '높은 평균 순위 + 낮은 선택률', ha='left', va='top', fontsize=9, color='goldenrod', alpha=0.4, fontweight='bold')
    ax.text(x_max, y_min_val, '낮은 평균 순위 + 높은 선택률', ha='right', va='bottom', fontsize=9, color='orange', alpha=0.4, fontweight='bold')
    ax.text(x_min, y_min_val, '낮은 평균 순위 + 낮은 선택률', ha='left', va='bottom', fontsize=9, color='steelblue', alpha=0.4, fontweight='bold')
    
    # Y축 뒤집기
    ax.invert_yaxis()
    
    ax.set_title(f'{tier}', fontsize=12, fontweight='bold')
    ax.set_xlabel('pick_rate')
    ax.set_ylabel('avg_rank')
    
# 빈 subplot 숨기기
for j in range(len(tiers_s), len(axes)):
    axes[j].set_visible(False)

# 범례
patches = [mpatches.Patch(color=c, label=l) for l, c in color_map.items()]
fig.legend(handles=patches, loc='lower center', ncol=4, fontsize=10, bbox_to_anchor=(0.5, -0.02))

plt.suptitle('챔피언 의사결정 매트릭스 (티어별)(평균등수)', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()
# Out:
# avg_rank 기준선 (중앙값): 4.446
# pick_rate 기준선 (중앙값): 0.142
#
# ========== 의사결정 매트릭스 ==========
#
# 높은 평균 순위 + 높은 선택률 (86개)
#        name    user_tier  avg_rank  pick_rate  is_outlier
#        lulu   challenger  3.580707   0.176664       False
#        lulu grand_master  3.583215   0.150226       False
#        lulu     platinum  3.599041   0.157138       False
#        lulu       master  3.637232   0.159815       False
# missfortune     platinum  3.748716   0.225239       False
#      thresh      diamond  3.753275   0.153695       False
#      thresh grand_master  3.779857   0.192488       False
#      thresh       master  3.788920   0.177280       False
# missfortune      diamond  3.820154   0.270401       False
#      thresh   challenger  3.826861   0.205243       False
# missfortune       master  3.877075   0.265232       False
# missfortune grand_master  3.916105   0.285793       False
#        ekko   challenger  3.939495   0.146209       False
# missfortune   challenger  3.956653   0.281732       False
#     chogath     platinum  4.093540   0.204796       False
#      soraka grand_master  4.170567   0.142184       False
#        fizz     platinum  4.196283   0.151030       False
#          vi     platinum  4.210446   0.254065       False
#     chogath       master  4.231734   0.237495       False
#     chogath      diamond  4.236818   0.263278       False
#       kayle grand_master  4.239705   0.225357       False
#         lux grand_master  4.242944   0.171951       False
#         lux     platinum  4.248681   0.172409       False
#         lux       master  4.252331   0.177155       False
#       kayle      diamond  4.257488   0.244538       False
#       kayle   challenger  4.259027   0.241867       False
#  blitzcrank     platinum  4.265518   0.264852       False
#    kassadin     platinum  4.283266   0.219949       False
#         lux   challenger  4.283622   0.200776       False
#      ezreal     platinum  4.283798   0.226681       False
#       kayle       master  4.289307   0.225347       False
#          vi      diamond  4.295269   0.298241       False
#        jinx       master  4.297291   0.214750       False
#       karma   challenger  4.298658   0.176214       False
#    kassadin      diamond  4.303474   0.298140       False
#      velkoz grand_master  4.307921   0.143059       False
#     chogath grand_master  4.308270   0.261491       False
#      velkoz      diamond  4.308581   0.141688       False
#        ashe      diamond  4.308854   0.230845       False
#       kayle     platinum  4.310383   0.212165       False
#        fizz      diamond  4.312888   0.143841       False
#        ashe     platinum  4.319829   0.219105       False
#    malphite     platinum  4.321133   0.225824       False
#      graves       master  4.324886   0.167859       False
#          vi       master  4.325414   0.318066       False
#        jinx     platinum  4.326148   0.203184       False
#      irelia      diamond  4.333081   0.215830       False
#    malphite       master  4.334924   0.243888       False
#       karma     platinum  4.336538   0.178452       False
#        jhin     platinum  4.342873   0.167574       False
#       annie     platinum  4.345026   0.151537       False
#      graves grand_master  4.346289   0.192113       False
#        jinx grand_master  4.348147   0.230786       False
#          vi grand_master  4.351645   0.339462       False
#      ezreal       master  4.359944   0.276292       False
#      irelia grand_master  4.362192   0.192863       False
#      rumble     platinum  4.362766   0.157489       False
#     chogath   challenger  4.363095   0.228854       False
#        jinx      diamond  4.364372   0.236533       False
#      ezreal      diamond  4.364636   0.242713       False
#    malphite      diamond  4.364799   0.284522       False
#      graves   challenger  4.369964   0.168969       False
#  blitzcrank      diamond  4.372286   0.312437       False
#       rakan      diamond  4.374310   0.175682       False
#      wukong     platinum  4.375515   0.230359       False
#        fizz   challenger  4.380104   0.144645       False
#    malphite grand_master  4.384001   0.261416       False
#          vi   challenger  4.384840   0.347147       False
#    kassadin grand_master  4.386743   0.300214       False
#        jinx   challenger  4.387240   0.210836       False
#       shaco     platinum  4.394887   0.166236       False
#      wukong      diamond  4.400709   0.273220       False
#       karma       master  4.401698   0.153297       False
#      ezreal grand_master  4.401854   0.292722       False
#    kassadin       master  4.405988   0.277468       False
#      wukong       master  4.413410   0.257688       False
#  blitzcrank       master  4.413483   0.307869       False
#        jhin      diamond  4.414814   0.143237       False
#      wukong grand_master  4.417297   0.287494       False
#        ashe grand_master  4.422084   0.223932       False
#      irelia   challenger  4.425640   0.201251       False
#    malphite   challenger  4.426982   0.231682       False
#      wukong   challenger  4.431011   0.235235       False
#        ashe       master  4.437919   0.229638       False
#       annie   challenger  4.438419   0.147210       False
#       xayah      diamond  4.446116   0.168987       False
#
# 높은 평균 순위 + 낮은 선택률 (42개)
#        name    user_tier  avg_rank  pick_rate  is_outlier
#        lulu      diamond  3.617053   0.136390       False
#      thresh     platinum  3.734722   0.134187       False
#        ekko     platinum  3.751350   0.117967       False
#        ekko      diamond  3.840582   0.088263       False
#      xerath     platinum  3.842056   0.055871       False
#      xerath      diamond  3.844109   0.044968       False
#      xerath   challenger  3.897864   0.077915       False
#        ekko grand_master  3.901731   0.101184       False
#      xerath grand_master  3.920008   0.061136       False
#      xerath       master  3.932803   0.067584       False
#        ekko       master  3.952605   0.117203       False
#   gangplank   challenger  3.983474   0.034072       False
#   gangplank     platinum  4.083934   0.106375       False
#   gangplank grand_master  4.095593   0.062149       False
#   gangplank      diamond  4.111578   0.131746       False
#   gangplank       master  4.142110   0.052646       False
#      soraka   challenger  4.170962   0.123323       False
#      soraka       master  4.188676   0.135669       False
#      soraka      diamond  4.216847   0.087407       False
#         lux      diamond  4.247391   0.121791       False
#      velkoz     platinum  4.251988   0.138891       False
#      velkoz       master  4.282658   0.127474       False
#      velkoz   challenger  4.283754   0.101201       False
#       xayah grand_master  4.315328   0.138469       False
#      soraka     platinum  4.323126   0.126051       False
#       rakan grand_master  4.334012   0.135104       False
#     caitlyn grand_master  4.345015   0.052819       False
#    jarvaniv grand_master  4.354502   0.099458       False
#        fizz       master  4.366251   0.133529       False
#       rakan       master  4.366929   0.130589       False
#       karma grand_master  4.376823   0.114080       False
#       kaisa     platinum  4.391756   0.133992       False
#    jarvaniv      diamond  4.393207   0.128574       False
#       xayah       master  4.403872   0.113750       False
#       fiora   challenger  4.403984   0.131294       False
#       rakan   challenger  4.404133   0.098086       False
#      khazix     platinum  4.415869   0.116785       False
#        fizz grand_master  4.429729   0.114267       False
# twistedfate      diamond  4.437696   0.120394       False
#       karma      diamond  4.437726   0.101150       False
# twistedfate grand_master  4.439639   0.122047       False
#       fiora grand_master  4.441853   0.117444       False
#
# 낮은 평균 순위 + 높은 선택률 (42개)
#        name    user_tier  avg_rank  pick_rate  is_outlier
#      irelia       master  4.447503   0.188628       False
#      rumble   challenger  4.447534   0.147147       False
#      irelia     platinum  4.448994   0.187913       False
#        jhin   challenger  4.456699   0.182195       False
#      graves      diamond  4.456964   0.184970       False
#        ashe   challenger  4.457873   0.220833       False
#  blitzcrank grand_master  4.461603   0.326229       False
#      ezreal   challenger  4.465024   0.294957       False
#        shen grand_master  4.470570   0.240967       False
#        shen      diamond  4.471428   0.263630       False
#        jhin       master  4.478401   0.170587       False
#      lucian     platinum  4.486289   0.165404       False
#       rakan     platinum  4.490933   0.157671       False
#    kassadin   challenger  4.491995   0.273549       False
#       shaco   challenger  4.518337   0.181507       False
#      khazix      diamond  4.518555   0.153292       False
#        jhin grand_master  4.520317   0.156054       False
#  blitzcrank   challenger  4.524042   0.302115       False
#      rumble      diamond  4.541538   0.167099       False
#       leona   challenger  4.544412   0.175663       False
#        shen       master  4.552043   0.218879       False
#       jayce   challenger  4.553593   0.168569       False
#       shaco       master  4.557261   0.153272       False
#       jayce     platinum  4.561737   0.184093       False
#       kaisa   challenger  4.568831   0.149337       False
#        shen   challenger  4.571077   0.218381       False
#       jayce       master  4.580069   0.187814       False
#       jayce      diamond  4.581794   0.201722       False
#        shen     platinum  4.603056   0.210098       False
#       jayce grand_master  4.621450   0.178780       False
#      lucian   challenger  4.649441   0.184747       False
#       poppy       master  4.657707   0.157788       False
# mordekaiser     platinum  4.671058   0.156852       False
#       poppy grand_master  4.673908   0.165810       False
# mordekaiser   challenger  4.685743   0.162450       False
#      lucian       master  4.689777   0.159702       False
#       leona grand_master  4.690437   0.143997       False
#       leona       master  4.724278   0.147379       False
#       poppy     platinum  4.725693   0.142894       False
# mordekaiser       master  4.746026   0.144827       False
#      lucian grand_master  4.765255   0.150038       False
#        sona     platinum  4.782033   0.143219       False
#
# 낮은 평균 순위 + 낮은 선택률 (85개)
#        name    user_tier  avg_rank  pick_rate  is_outlier
#       annie       master  4.453245   0.132053       False
#     caitlyn      diamond  4.458969   0.092328       False
#       annie      diamond  4.479307   0.124987       False
#      rumble       master  4.480328   0.140548       False
#       xayah   challenger  4.484185   0.092568       False
#       neeko       master  4.484663   0.100338       False
#       neeko   challenger  4.484769   0.115015       False
#     xinzhao       master  4.489646   0.102102       False
# twistedfate     platinum  4.493893   0.092573       False
# twistedfate       master  4.495857   0.095121       False
#     xinzhao   challenger  4.500950   0.085623       False
#      syndra   challenger  4.503487   0.105868       False
#         zoe       master  4.511881   0.125310       False
#        ahri   challenger  4.515355   0.106344       False
#         zoe   challenger  4.516951   0.112938       False
#    jarvaniv       master  4.530035   0.089766       False
#         zoe     platinum  4.533877   0.105114       False
#     xinzhao      diamond  4.538838   0.102887       False
#      rumble grand_master  4.539143   0.127012       False
#       shaco      diamond  4.539830   0.130185       False
#       annie grand_master  4.545580   0.108664       False
#     caitlyn       master  4.545698   0.042024       False
#       kaisa      diamond  4.549279   0.138806       False
#      syndra       master  4.549766   0.096284       False
#     xinzhao grand_master  4.550897   0.087114       False
#        ahri       master  4.551583   0.097986       False
#         zoe grand_master  4.557246   0.137318       False
#         zoe      diamond  4.562320   0.082901       False
#       neeko grand_master  4.562380   0.078196       False
#      graves     platinum  4.563846   0.132718       False
#        sona   challenger  4.565250   0.101539       False
# twistedfate   challenger  4.565317   0.054404       False
#        sona       master  4.566602   0.128112       False
#       fiora       master  4.566720   0.109696       False
#      darius   challenger  4.568720   0.060723       False
#       xayah     platinum  4.571988   0.126194       False
#      syndra     platinum  4.572745   0.101566       False
#     xinzhao     platinum  4.573386   0.133706       False
#        sona grand_master  4.577482   0.136968       False
#        ahri     platinum  4.577603   0.102242       False
#      syndra grand_master  4.578343   0.085012       False
#       kaisa       master  4.583845   0.136607       False
#    jarvaniv     platinum  4.584655   0.131951       False
#       shaco grand_master  4.590936   0.127225       False
#       fiora      diamond  4.602877   0.100622       False
#      darius       master  4.605071   0.083886       False
#       neeko     platinum  4.610749   0.109546       False
#       neeko      diamond  4.614700   0.053766       False
#        ahri      diamond  4.623341   0.064489       False
#      syndra      diamond  4.639368   0.061317       False
#       poppy   challenger  4.641149   0.137625       False
#        ahri grand_master  4.650481   0.089640       False
#      khazix       master  4.653376   0.117665       False
#    jarvaniv   challenger  4.660247   0.077965       False
#     caitlyn     platinum  4.664032   0.070713       False
#       kaisa grand_master  4.670805   0.124923       False
#      darius grand_master  4.671019   0.068966       False
#      khazix grand_master  4.682871   0.115518       False
#     caitlyn   challenger  4.685059   0.020183       False
#      khazix   challenger  4.695615   0.115841       False
#       fiora     platinum  4.706357   0.104672       False
#      lucian      diamond  4.736837   0.136252       False
#        sona      diamond  4.740893   0.116429       False
#      darius      diamond  4.755359   0.105102       False
#       poppy      diamond  4.757986   0.114252       False
#       leona     platinum  4.767275   0.123192       False
#      darius     platinum  4.769713   0.103671       False
# mordekaiser grand_master  4.796843   0.122022       False
#    masteryi      diamond  4.826568   0.076269       False
#       leona      diamond  4.837720   0.098495       False
#       yasuo      diamond  4.858272   0.076457       False
#    masteryi   challenger  4.875949   0.047810       False
#       ziggs      diamond  4.879209   0.059807       False
# mordekaiser      diamond  4.903813   0.087797       False
#       ziggs   challenger  4.909639   0.018694       False
#    masteryi       master  4.921665   0.055899       False
#    masteryi     platinum  4.930306   0.103308       False
#       yasuo   challenger  4.931009   0.051689       False
#    masteryi grand_master  4.951885   0.040811       False
#       yasuo     platinum  4.958491   0.106765       False
#       yasuo       master  4.961844   0.056725       False
#       ziggs grand_master  4.998325   0.022401       False
#       yasuo grand_master  5.012770   0.041137       False
#       ziggs     platinum  5.032290   0.053129       False
#       ziggs       master  5.082359   0.024609       False

# %%
# 태블로 대시보드 작업용 계산결과(사분면 제작용)
tier_medians = champ_stats_by_tier_except.groupby('user_tier').agg(
    avg_rank_median=('avg_rank', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians)
# Out:
#       user_tier  avg_rank_median  pick_rate_median
# 0    challenger         4.465024          0.147210
# 1       diamond         4.437726          0.136252
# 2  grand_master         4.429729          0.137318
# 3        master         4.453245          0.140548
# 4      platinum         4.394887          0.143219

# %% [markdown]
# ##### **(2) 티어별 시너지 승률/선택률 분포(의사결정 사분면 제작용)**

# %%
# 티어별 중앙값 계산
tier_medians_combo = combo_stats_by_tier_except.groupby('user_tier').agg(
    avg_rank_median=('avg_rank', 'median'),
    pick_rate_median=('pick_rate', 'median')
).reset_index()

print(tier_medians_combo)
# Out:
#       user_tier  avg_rank_median  pick_rate_median
# 0    challenger         4.314538          0.181151
# 1       diamond         4.277574          0.180894
# 2  grand_master         4.337433          0.184161
# 3        master         4.316764          0.183486
# 4      platinum         4.219913          0.168334

# %%
# 왜도(skewness) 확인 → 0에 가까울수록 정규분포에 가까움
print(f"avg_rank  왜도: {combo_stats_by_tier_except['avg_rank'].skew():.3f}")
print(f"pick_rate 왜도: {combo_stats_by_tier_except['pick_rate'].skew():.3f}")
# Out:
# avg_rank  왜도: -0.403
# pick_rate 왜도: 1.141

# %%
import matplotlib.patches as mpatches

# ================================
# 기준선 설정 (중앙값 기준)
# ================================
avg_rank_median_c  = combo_stats_by_tier_except['avg_rank'].median()
pick_rate_median_c = combo_stats_by_tier_except['pick_rate'].median()

print(f"avg_rank 기준선 (중앙값): {avg_rank_median_c:.3f}")
print(f"pick_rate 기준선 (중앙값): {pick_rate_median_c:.3f}")

# ================================
# 사분면 분류
# ================================
def classify_matrix_combo(row):
    high_rank = row['avg_rank']  <= avg_rank_median_c
    high_pick = row['pick_rate'] >= pick_rate_median_c
    
    if high_rank and high_pick:
        return '높은 평균 순위 + 높은 선택률'
    elif high_rank and not high_pick:
        return '높은 평균 순위 + 낮은 선택률'
    elif not high_rank and high_pick:
        return '낮은 평균 순위 + 높은 선택률'
    else:
        return '낮은 평균 순위 + 낮은 선택률'

combo_stats_by_tier_except['matrix_type'] = combo_stats_by_tier_except.apply(classify_matrix_combo, axis=1)

# ================================
# 의사결정 매트릭스 출력
# ================================
print("\n========== 시너지 의사결정 매트릭스 ==========")
for matrix_type in ['높은 평균 순위 + 높은 선택률', '높은 평균 순위 + 낮은 선택률',
                    '낮은 평균 순위 + 높은 선택률', '낮은 평균 순위 + 낮은 선택률']:
    subset = combo_stats_by_tier_except[combo_stats_by_tier_except['matrix_type'] == matrix_type]\
        .sort_values('avg_rank', ascending=True)\
        [['combo_list_active', 'user_tier', 'avg_rank', 'pick_rate']]
    print(f"\n{matrix_type} ({len(subset)}개)")
    print(subset.to_string(index=False))

# ================================
# 시각화 - 티어별 사분면 산점도
# ================================
tiers_c = combo_stats_by_tier_except['user_tier'].unique()
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

color_map = {
    '높은 평균 순위 + 높은 선택률': 'red',
    '높은 평균 순위 + 낮은 선택률': 'gold',
    '낮은 평균 순위 + 높은 선택률': 'orange',
    '낮은 평균 순위 + 낮은 선택률': 'steelblue'
}

for i, tier in enumerate(tiers_c):
    ax = axes[i]
    tier_df = combo_stats_by_tier_except[combo_stats_by_tier_except['user_tier'] == tier]

    # Y축 범위 미리 계산
    y_min_val = tier_df['avg_rank'].min()
    y_max_val = tier_df['avg_rank'].max()

    # 기준선
    ax.axvline(x=pick_rate_median_c, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=avg_rank_median_c,  color='gray', linestyle='--', alpha=0.5)

    # 사분면 배경색
    ax.axvspan(pick_rate_median_c, tier_df['pick_rate'].max() + 0.01,
            ymin=0.5, alpha=0.05, color='red')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_c,
            ymin=0.5, alpha=0.05, color='gold')
    ax.axvspan(pick_rate_median_c, tier_df['pick_rate'].max() + 0.01,
            ymax=0.5, alpha=0.05, color='orange')
    ax.axvspan(tier_df['pick_rate'].min() - 0.01, pick_rate_median_c,
            ymax=0.5, alpha=0.05, color='steelblue')

    # 산점도
    for mtype, color in color_map.items():
        subset = tier_df[tier_df['matrix_type'] == mtype]
        ax.scatter(subset['pick_rate'], subset['avg_rank'],
                color=color, alpha=0.6, s=60, label=mtype)

    # 시너지 이름 표시
    for _, row in tier_df.iterrows():
        ax.annotate(row['combo_list_active'], (row['pick_rate'], row['avg_rank']),
                    fontsize=7, ha='left', va='bottom')

    # 사분면 라벨
    x_min = tier_df['pick_rate'].min()
    x_max = tier_df['pick_rate'].max()
    
    ax.text(x_max, y_max_val, '높은 평균 순위 + 높은 선택률', ha='right', va='top',   fontsize=9, color='red',       alpha=0.4, fontweight='bold')
    ax.text(x_min, y_max_val, '높은 평균 순위 + 낮은 선택률', ha='left',  va='top',   fontsize=9, color='goldenrod', alpha=0.4, fontweight='bold')
    ax.text(x_max, y_min_val, '낮은 평균 순위 + 높은 선택률', ha='right', va='bottom', fontsize=9, color='orange',   alpha=0.4, fontweight='bold')
    ax.text(x_min, y_min_val, '낮은 평균 순위 + 낮은 선택률', ha='left',  va='bottom', fontsize=9, color='steelblue',alpha=0.4, fontweight='bold')

    # Y축 뒤집기
    ax.invert_yaxis()

    ax.set_title(f'{tier}', fontsize=12, fontweight='bold')
    ax.set_xlabel('pick_rate')
    ax.set_ylabel('avg_rank')

# 빈 subplot 숨기기
for j in range(len(tiers_c), len(axes)):
    axes[j].set_visible(False)

# 범례
patches = [mpatches.Patch(color=c, label=l) for l, c in color_map.items()]
fig.legend(handles=patches, loc='lower center', ncol=4, fontsize=10, bbox_to_anchor=(0.5, -0.02))

plt.suptitle('시너지 의사결정 매트릭스 (티어별)(평균등수)', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()
# Out:
# avg_rank 기준선 (중앙값): 4.306
# pick_rate 기준선 (중앙값): 0.181
#
# ========== 시너지 의사결정 매트릭스 ==========
#
# 높은 평균 순위 + 높은 선택률 (34개)
# combo_list_active    user_tier  avg_rank  pick_rate
#         Mercenary     platinum  3.883806   0.300795
#          Valkyrie      diamond  3.885558   0.181782
#         Mercenary       master  3.934085   0.303115
#         Mercenary      diamond  3.953098   0.363588
#         Mercenary grand_master  3.957731   0.330490
#            Mystic   challenger  3.959698   0.185336
#         Mercenary   challenger  3.973319   0.304811
#          Valkyrie   challenger  3.988850   0.205343
#          Valkyrie grand_master  4.003127   0.187956
#          Valkyrie       master  4.006786   0.182510
#            Mystic       master  4.011801   0.184461
#            Mystic grand_master  4.043202   0.184980
#        ManaReaver     platinum  4.108875   0.227217
#        ManaReaver      diamond  4.155331   0.306992
#        ManaReaver grand_master  4.157765   0.304165
#            Chrono     platinum  4.169804   0.405842
#           Brawler     platinum  4.183461   0.214939
#           Blaster     platinum  4.189069   0.254606
#        ManaReaver       master  4.195235   0.290417
#        ManaReaver   challenger  4.204804   0.298980
#            Sniper      diamond  4.217302   0.189849
#            Chrono      diamond  4.219358   0.554167
#         Celestial     platinum  4.223041   0.315672
#          Sorcerer     platinum  4.235959   0.238976
#           Blaster       master  4.242724   0.295759
#            Chrono       master  4.245350   0.503853
#            Chrono grand_master  4.259336   0.582404
#           Blaster      diamond  4.265158   0.279179
#          Sorcerer      diamond  4.267176   0.217247
#          Sorcerer   challenger  4.277770   0.270216
#         Celestial      diamond  4.287971   0.356968
#         Celestial       master  4.290216   0.347804
#           Blaster grand_master  4.292110   0.310355
#           Blaster   challenger  4.302806   0.315721
#
# 높은 평균 순위 + 낮은 선택률 (21개)
# combo_list_active    user_tier  avg_rank  pick_rate
#          Valkyrie     platinum  3.859240   0.148702
#             Rebel grand_master  3.900744   0.117684
#             Rebel   challenger  3.949909   0.110153
#             Rebel       master  3.967263   0.111210
#            Mystic      diamond  3.978747   0.123763
#            Mystic     platinum  3.993820   0.166099
#     Demolitionist     platinum  3.997015   0.117506
#     Demolitionist   challenger  4.007997   0.089184
#              Void     platinum  4.054264   0.053634
#     Demolitionist       master  4.079857   0.097761
#             Rebel      diamond  4.134243   0.125437
#     Demolitionist grand_master  4.135970   0.105315
#       Infiltrator     platinum  4.170932   0.170569
#     Demolitionist      diamond  4.178121   0.170493
#              Void      diamond  4.196398   0.072667
#         MechPilot     platinum  4.216785   0.132214
#          DarkStar     platinum  4.224522   0.148143
#            Sniper     platinum  4.230675   0.180183
#         Protector grand_master  4.289865   0.140308
#       Infiltrator      diamond  4.290988   0.180007
#          DarkStar   challenger  4.292543   0.157560
#
# 낮은 평균 순위 + 높은 선택률 (21개)
# combo_list_active    user_tier  avg_rank  pick_rate
#          Sorcerer       master  4.309180   0.262617
#         Celestial   challenger  4.311412   0.350629
#         Celestial grand_master  4.313556   0.358329
#            Chrono   challenger  4.317665   0.478861
#           Brawler      diamond  4.320158   0.276700
#           Brawler       master  4.320415   0.255361
#          Sorcerer grand_master  4.348941   0.260955
#            Sniper grand_master  4.357299   0.183342
#       Blademaster      diamond  4.364488   0.288832
#            Sniper       master  4.364602   0.184987
#       Blademaster grand_master  4.383415   0.270110
#           Brawler grand_master  4.384481   0.279640
#            Sniper   challenger  4.412042   0.183072
#           Brawler   challenger  4.432868   0.246669
#       Blademaster   challenger  4.443229   0.261820
#       Blademaster       master  4.460623   0.253384
#       Blademaster     platinum  4.487888   0.236533
#          Vanguard      diamond  4.522746   0.228788
#          Vanguard grand_master  4.553790   0.231341
#          Vanguard       master  4.567252   0.203703
#          Vanguard     platinum  4.570596   0.193891
#
# 낮은 평균 순위 + 낮은 선택률 (34개)
# combo_list_active    user_tier  avg_rank  pick_rate
#         Protector   challenger  4.310615   0.105374
#         Protector       master  4.313707   0.135356
#              Void       master  4.319820   0.041661
#         Protector      diamond  4.322692   0.175036
#              Void grand_master  4.325926   0.043897
#       Infiltrator   challenger  4.328656   0.179231
#          DarkStar       master  4.353270   0.131990
#          DarkStar      diamond  4.359959   0.072793
#       Infiltrator       master  4.361435   0.166358
#       Infiltrator grand_master  4.365210   0.151701
#          DarkStar grand_master  4.375758   0.096986
#         MechPilot       master  4.389274   0.122707
#         MechPilot   challenger  4.397170   0.137917
#         MechPilot      diamond  4.405619   0.116477
#             Rebel     platinum  4.418367   0.110776
#        Cybernetic   challenger  4.422516   0.136365
#      StarGuardian       master  4.440986   0.127411
#         Protector     platinum  4.444347   0.162721
#      StarGuardian   challenger  4.464985   0.115058
#              Void   challenger  4.465967   0.032168
#        Cybernetic grand_master  4.466415   0.102776
#      StarGuardian grand_master  4.471423   0.137419
#        Cybernetic     platinum  4.473677   0.098472
#       SpacePirate   challenger  4.476136   0.066062
#        Cybernetic      diamond  4.476353   0.080898
#         MechPilot grand_master  4.486460   0.101601
#      StarGuardian     platinum  4.490001   0.114999
#      StarGuardian      diamond  4.492792   0.085555
#        Cybernetic       master  4.508665   0.106843
#       SpacePirate       master  4.527359   0.095346
#          Vanguard   challenger  4.553869   0.165718
#       SpacePirate grand_master  4.558449   0.091258
#       SpacePirate      diamond  4.583303   0.136726
#       SpacePirate     platinum  4.645733   0.115856

# %%
champ_stats_by_tier_except.head(2)
combo_stats_by_tier_except.head(2)
# Out:
#   combo_list_active   user_tier  pick_count  avg_rank  win_rate  top4_rate  \
# 0       Blademaster  challenger       20926  4.443229  0.125538   0.509271
# 1       Blademaster     diamond       22950  4.364488  0.132244   0.524793
#
#    pick_rate        matrix_type
# 0   0.261820  낮은 평균 순위 + 높은 선택률
# 1   0.288832  낮은 평균 순위 + 높은 선택률

# %%
# 사분면과 티어 데이터를 함께 Export _champ version

# 사분면 데이터
quadrant_data = champ_stats_by_tier_except.copy()

avg_rank_median = quadrant_data['avg_rank'].median()
pick_rate_median = quadrant_data['pick_rate'].median()

def assign_quadrant(row):
    if row['avg_rank'] <= avg_rank_median and row['pick_rate'] > pick_rate_median:
        return 'Q1: High Rank, High Pick'
    elif row['avg_rank'] > avg_rank_median and row['pick_rate'] > pick_rate_median:
        return 'Q2: Low Rank, High Pick'
    elif row['avg_rank'] > avg_rank_median and row['pick_rate'] <= pick_rate_median:
        return 'Q3: Low Rank, Low Pick'
    else:
        return 'Q4: High Rank, Low Pick'

quadrant_data['quadrant'] = quadrant_data.apply(assign_quadrant, axis=1)

# Export
practice_output = quadrant_data[[
    'user_tier',       
    'name',
    'cost',
    'avg_rank',
    'win_rate',
    'top4_rate',
    'pick_rate',
    'quadrant',
]].reset_index(drop=True)

# 저장
practice_output.to_csv('./data/champion_scatter_quadrant_table_with_tier.csv', index=False, encoding='utf-8-sig')

practice_output.head()
# Out:
#       user_tier  name  cost  avg_rank  win_rate  top4_rate  pick_rate  \
# 0    challenger  ahri     2  4.515355  0.141428   0.495941   0.106344
# 1       diamond  ahri     2  4.623341  0.119048   0.480874   0.064489
# 2  grand_master  ahri     2  4.650481  0.135901   0.467281   0.089640
# 3        master  ahri     2  4.551583  0.138151   0.490552   0.097986
# 4      platinum  ahri     2  4.577603  0.116182   0.488369   0.102242
#
#                  quadrant
# 0  Q3: Low Rank, Low Pick
# 1  Q3: Low Rank, Low Pick
# 2  Q3: Low Rank, Low Pick
# 3  Q3: Low Rank, Low Pick
# 4  Q3: Low Rank, Low Pick

# %%
# 사분면과 티어 데이터를 함께 Export _comb version

# 사분면 데이터
quadrant_data = combo_stats_by_tier_except.copy()

avg_rank_median = quadrant_data['avg_rank'].median()
pick_rate_median = quadrant_data['pick_rate'].median()

def assign_quadrant(row):
    if row['avg_rank'] <= avg_rank_median and row['pick_rate'] > pick_rate_median:
        return 'Q1: High Rank, High Pick'
    elif row['avg_rank'] > avg_rank_median and row['pick_rate'] > pick_rate_median:
        return 'Q2: Low Rank, High Pick'
    elif row['avg_rank'] > avg_rank_median and row['pick_rate'] <= pick_rate_median:
        return 'Q3: Low Rank, Low Pick'
    else:
        return 'Q4: High Rank, Low Pick'

quadrant_data['quadrant'] = quadrant_data.apply(assign_quadrant, axis=1)

# Export
practice_output2 = quadrant_data[[
    'user_tier',       
    'combo_list_active',
    'avg_rank',
    'win_rate',
    'top4_rate',
    'pick_rate',
    'quadrant',
]].reset_index(drop=True)

# 저장
practice_output2.to_csv('./data/combination_scatter_quadrant_table_with_tier.csv',  index=False, encoding='utf-8-sig')

practice_output2.head()
# Out:
#       user_tier combo_list_active  avg_rank  win_rate  top4_rate  pick_rate  \
# 0    challenger       Blademaster  4.443229  0.125538   0.509271   0.261820
# 1       diamond       Blademaster  4.364488  0.132244   0.524793   0.288832
# 2  grand_master       Blademaster  4.383415  0.128947   0.522224   0.270110
# 3        master       Blademaster  4.460623  0.126055   0.507283   0.253384
# 4      platinum       Blademaster  4.487888  0.125954   0.500961   0.236533
#
#                   quadrant
# 0  Q2: Low Rank, High Pick
# 1  Q2: Low Rank, High Pick
# 2  Q2: Low Rank, High Pick
# 3  Q2: Low Rank, High Pick
# 4  Q2: Low Rank, High Pick
